# %% [markdown]
# # ***Projet 09 - Etude de marché - Préparation des données - FIRST RUN***

# %% [markdown]
# ---
# ## Partie 1 - Importation - Préparation

# %% [markdown]
# ### 1. Import des librairies (ok)
# ---

# %%
# Mes imports de lib de base
import pandas as pd # Pour travail avec les df
import numpy as np # Tout ce qui est fct math avec numpy, tjs utile

# Pour les graphiques
import matplotlib.pyplot as plt # Graphes avec matplotlib
import seaborn as sns # Graphes avec seaborn
sns.set_style('darkgrid', {'grid.color': '.5', 'grid.linestyle': ':'}) # Défini un fond de graphe que ce soit pour sns ou plt

# Pour les stats et autre
import scipy.stats as stats # Pour des stats avec scipy
import statsmodels.api as sm # Pour des régressions linéaires ou autre

# Pour le clustering et PCA
import sklearn as sk
import scipy as sp
# import pca as pca
from sklearn.cluster import KMeans # Clustering avec KMeans
from sklearn.decomposition import PCA # Pour calcul des composantes principales

# %% [markdown]
# ### 2. Infos sur les fichiers (df) - Préparation
# ---

# %% [markdown]
# #### *2.1. Disponibilité*

# %%
# On prendra les données de ce df comme base à laquelle on ajoutera d'autres données
# Source : OCR

# %%
# Import du csv dispo alimentaire par pays en 2017
# On part du principe que ces datas sont 'safe' (source : FAO) et qu'il n'y a pas de doublons dans les données, ce qui nous éviteras de les tester
data_dispo_alim = pd.read_csv('DisponibiliteAlimentaire_2017.csv')
data_dispo_alim
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 0               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176595          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176596          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176597          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176598          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176599          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément                                            Élément  \
# 0               5511                                         Production
# 1               5611                            Importations - Quantité
# 2               5072                                 Variation de stock
# 3               5911                            Exportations - Quantité
# 4               5301                           Disponibilité intérieure
# ...              ...                                                ...
# 176595          5142                                         Nourriture
# 176596           645  Disponibilité alimentaire en quantité (kg/pers...
# 176597           664     Disponibilité alimentaire (Kcal/personne/jour)
# 176598           674  Disponibilité de protéines en quantité (g/pers...
# 176599           684  Disponibilité de matière grasse en quantité (g...
#
#         Code Produit          Produit  Code année  Année               Unité  \
# 0               2511  Blé et produits        2017   2017  Milliers de tonnes
# 1               2511  Blé et produits        2017   2017  Milliers de tonnes
# 2               2511  Blé et produits        2017   2017  Milliers de tonnes
# 3               2511  Blé et produits        2017   2017  Milliers de tonnes
# 4               2511  Blé et produits        2017   2017  Milliers de tonnes
# ...              ...              ...         ...    ...                 ...
# 176595          2899     Miscellanees        2017   2017  Milliers de tonnes
# 176596          2899     Miscellanees        2017   2017                  kg
# 176597          2899     Miscellanees        2017   2017  Kcal/personne/jour
# 176598          2899     Miscellanees        2017   2017     g/personne/jour
# 176599          2899     Miscellanees        2017   2017     g/personne/jour
#
#          Valeur Symbole Description du Symbole
# 0       4281.00       S  Données standardisées
# 1       2302.00       S  Données standardisées
# 2       -119.00       S  Données standardisées
# 3          0.00       S  Données standardisées
# 4       6701.00       S  Données standardisées
# ...         ...     ...                    ...
# 176595    19.00       S  Données standardisées
# 176596     1.33      Fc        Donnée calculée
# 176597     1.00      Fc        Donnée calculée
# 176598     0.04      Fc        Donnée calculée
# 176599     0.02      Fc        Donnée calculée
#
# [176600 rows x 14 columns]

# %%
# Taille du dataset
data_dispo_alim.shape
# Out:
# (176600, 14)

# %%
# Infos sur le dataset
# On voit qu'il n'y à pas de manquants
print('Infos sur le dataset :')
print(data_dispo_alim.info())
print('')
print('Manquants sur le dataset :')
print(data_dispo_alim.isna().sum())
# Out:
# Infos sur le dataset :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176600 entries, 0 to 176599
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Code Domaine            176600 non-null  object
#  1   Domaine                 176600 non-null  object
#  2   Code zone               176600 non-null  int64
#  3   Zone                    176600 non-null  object
#  4   Code Élément            176600 non-null  int64
#  5   Élément                 176600 non-null  object
#  6   Code Produit            176600 non-null  int64
#  7   Produit                 176600 non-null  object
#  8   Code année              176600 non-null  int64
#  9   Année                   176600 non-null  int64
#  10  Unité                   176600 non-null  object
#  11  Valeur                  176600 non-null  float64
#  12  Symbole                 176600 non-null  object
#  13  Description du Symbole  176600 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 18.9+ MB
# None
#
# Manquants sur le dataset :
# Code Domaine              0
# Domaine                   0
# Code zone                 0
# Zone                      0
# Code Élément              0
# Élément                   0
# Code Produit              0
# Produit                   0
# Code année                0
# Année                     0
# Unité                     0
# Valeur                    0
# Symbole                   0
# Description du Symbole    0
# dtype: int64

# %%
# Describe sur le dataset
# Ce dataset est sur l'année 2017, donc à voir avec les autres data comment les caler
# Note : On a 174 pays
data_dispo_alim.describe(include = 'all')
# Out:
#        Code Domaine                      Domaine      Code zone    Zone  \
# count        176600                       176600  176600.000000  176600
# unique            1                            1            NaN     174
# top             FBS  Nouveaux Bilans Alimentaire            NaN   Tchad
# freq         176600                       176600            NaN    1416
# mean            NaN                          NaN     125.474740     NaN
# std             NaN                          NaN      72.941699     NaN
# min             NaN                          NaN       1.000000     NaN
# 25%             NaN                          NaN      63.000000     NaN
# 50%             NaN                          NaN     120.000000     NaN
# 75%             NaN                          NaN     188.000000     NaN
# max             NaN                          NaN     276.000000     NaN
#
#          Code Élément                   Élément   Code Produit  \
# count   176600.000000                    176600  176600.000000
# unique            NaN                        17            NaN
# top               NaN  Disponibilité intérieure            NaN
# freq              NaN                     15905            NaN
# mean      3810.052894                       NaN    2628.778545
# std       2211.790089                       NaN      91.993247
# min        645.000000                       NaN    2511.000000
# 25%        684.000000                       NaN    2556.000000
# 50%       5142.000000                       NaN    2612.000000
# 75%       5301.000000                       NaN    2732.000000
# max       5911.000000                       NaN    2899.000000
#
#                  Produit  Code année     Année               Unité  \
# count             176600    176600.0  176600.0              176600
# unique                98         NaN       NaN                   4
# top     Maïs et produits         NaN       NaN  Milliers de tonnes
# freq                2593         NaN       NaN              118487
# mean                 NaN      2017.0    2017.0                 NaN
# std                  NaN         0.0       0.0                 NaN
# min                  NaN      2017.0    2017.0                 NaN
# 25%                  NaN      2017.0    2017.0                 NaN
# 50%                  NaN      2017.0    2017.0                 NaN
# 75%                  NaN      2017.0    2017.0                 NaN
# max                  NaN      2017.0    2017.0                 NaN
#
#                Valeur Symbole Description du Symbole
# count   176600.000000  176600                 176600
# unique            NaN       2                      2
# top               NaN       S  Données standardisées
# freq              NaN  118487                 118487
# mean       210.554918     NaN                    NaN
# std       4762.047787     NaN                    NaN
# min     -10388.000000     NaN                    NaN
# 25%          0.000000     NaN                    NaN
# 50%          0.120000     NaN                    NaN
# 75%          8.462500     NaN                    NaN
# max     758548.000000     NaN                    NaN

# %%
# Mapping des colonnes
# On récupère l'entête sous forme de liste
col_df = list(data_dispo_alim.columns)
# On défini les valeurs de remplacement (sera identique pour le df population)
col_replace = ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# En premier les éléments à remplacer, en second la valeur de remplacement
replace_dict = dict(zip(col_df, col_replace)) # Mise des données sous  forme de dico
print(replace_dict)
# On passe le dico créé dans le rename
data_dispo_alim = data_dispo_alim.rename(columns = replace_dict)
data_dispo_alim.head()
# Out:
# {'Code Domaine': 'domain_code', 'Domaine': 'domaine', 'Code zone': 'zone_code', 'Zone': 'zone', 'Code Élément': 'item_code', 'Élément': 'item', 'Code Produit': 'product_code', 'Produit': 'product', 'Code année': 'year_code', 'Année': 'year', 'Unité': 'unity', 'Valeur': 'value', 'Symbole': 'symbole', 'Description du Symbole': 'symbole_descr'}
#   domain_code                      domaine  zone_code         zone  item_code  \
# 0         FBS  Nouveaux Bilans Alimentaire          2  Afghanistan       5511
# 1         FBS  Nouveaux Bilans Alimentaire          2  Afghanistan       5611
# 2         FBS  Nouveaux Bilans Alimentaire          2  Afghanistan       5072
# 3         FBS  Nouveaux Bilans Alimentaire          2  Afghanistan       5911
# 4         FBS  Nouveaux Bilans Alimentaire          2  Afghanistan       5301
#
#                        item  product_code          product  year_code  year  \
# 0                Production          2511  Blé et produits       2017  2017
# 1   Importations - Quantité          2511  Blé et produits       2017  2017
# 2        Variation de stock          2511  Blé et produits       2017  2017
# 3   Exportations - Quantité          2511  Blé et produits       2017  2017
# 4  Disponibilité intérieure          2511  Blé et produits       2017  2017
#
#                 unity   value symbole          symbole_descr
# 0  Milliers de tonnes  4281.0       S  Données standardisées
# 1  Milliers de tonnes  2302.0       S  Données standardisées
# 2  Milliers de tonnes  -119.0       S  Données standardisées
# 3  Milliers de tonnes     0.0       S  Données standardisées
# 4  Milliers de tonnes  6701.0       S  Données standardisées

# %%
# Nombre de pays présents dans le df_dispo
len(data_dispo_alim['zone'].unique())
# Out:
# 174

# %% [markdown]
# ##### Calcul des totaux par pays

# %%
# Equation du P4 pour vérif certaines choses au niveau de la dipo alim

# Production + Importation - Exportation + Variation
# = Dispo =
# Aliments animaux + Autres utilisations + Nourriture + Pertes + Semence + Traitement

# %%
# gb sur zone et item pour avoir la somme de chaque item par zone
temp_total = data_dispo_alim.groupby(['zone', 'item']).agg({'value' : 'sum'}).reset_index()
temp_total
# Out:
#               zone                                               item    value
# 0      Afghanistan                              Aliments pour animaux   456.00
# 1      Afghanistan              Autres utilisations (non alimentaire)    94.00
# 2      Afghanistan     Disponibilité alimentaire (Kcal/personne/jour)  1997.00
# 3      Afghanistan  Disponibilité alimentaire en quantité (kg/pers...   357.31
# 4      Afghanistan  Disponibilité de matière grasse en quantité (g...    30.63
# ...            ...                                                ...      ...
# 2834  Îles Salomon                                         Production  1059.00
# 2835  Îles Salomon                                            Résidus    -3.00
# 2836  Îles Salomon                                           Semences     0.00
# 2837  Îles Salomon                                         Traitement   309.00
# 2838  Îles Salomon                                 Variation de stock    31.00
#
# [2839 rows x 3 columns]

# %%
# On rajoute les données calculées à la suite du df de base et on précise ce que c'est
# On reset aussi l'index pour que ce soit propre
df_dispo_alim = pd.concat([data_dispo_alim, temp_total]).fillna({ 'product' : 'Total', 'year' : 2017}).reset_index(drop = True)
df_dispo_alim
# Out:
#        domain_code                      domaine  zone_code          zone  \
# 0              FBS  Nouveaux Bilans Alimentaire        2.0   Afghanistan
# 1              FBS  Nouveaux Bilans Alimentaire        2.0   Afghanistan
# 2              FBS  Nouveaux Bilans Alimentaire        2.0   Afghanistan
# 3              FBS  Nouveaux Bilans Alimentaire        2.0   Afghanistan
# 4              FBS  Nouveaux Bilans Alimentaire        2.0   Afghanistan
# ...            ...                          ...        ...           ...
# 179434         NaN                          NaN        NaN  Îles Salomon
# 179435         NaN                          NaN        NaN  Îles Salomon
# 179436         NaN                          NaN        NaN  Îles Salomon
# 179437         NaN                          NaN        NaN  Îles Salomon
# 179438         NaN                          NaN        NaN  Îles Salomon
#
#         item_code                      item  product_code          product  \
# 0          5511.0                Production        2511.0  Blé et produits
# 1          5611.0   Importations - Quantité        2511.0  Blé et produits
# 2          5072.0        Variation de stock        2511.0  Blé et produits
# 3          5911.0   Exportations - Quantité        2511.0  Blé et produits
# 4          5301.0  Disponibilité intérieure        2511.0  Blé et produits
# ...           ...                       ...           ...              ...
# 179434        NaN                Production           NaN            Total
# 179435        NaN                   Résidus           NaN            Total
# 179436        NaN                  Semences           NaN            Total
# 179437        NaN                Traitement           NaN            Total
# 179438        NaN        Variation de stock           NaN            Total
#
#         year_code    year               unity   value symbole  \
# 0          2017.0  2017.0  Milliers de tonnes  4281.0       S
# 1          2017.0  2017.0  Milliers de tonnes  2302.0       S
# 2          2017.0  2017.0  Milliers de tonnes  -119.0       S
# 3          2017.0  2017.0  Milliers de tonnes     0.0       S
# 4          2017.0  2017.0  Milliers de tonnes  6701.0       S
# ...           ...     ...                 ...     ...     ...
# 179434        NaN  2017.0                 NaN  1059.0     NaN
# 179435        NaN  2017.0                 NaN    -3.0     NaN
# 179436        NaN  2017.0                 NaN     0.0     NaN
# 179437        NaN  2017.0                 NaN   309.0     NaN
# 179438        NaN  2017.0                 NaN    31.0     NaN
#
#                 symbole_descr
# 0       Données standardisées
# 1       Données standardisées
# 2       Données standardisées
# 3       Données standardisées
# 4       Données standardisées
# ...                       ...
# 179434                    NaN
# 179435                    NaN
# 179436                    NaN
# 179437                    NaN
# 179438                    NaN
#
# [179439 rows x 14 columns]

# %%
# On ne touche à rien, on prendra les données qui nous intéressent une fois toutes les données dans un seul df

# %% [markdown]
# #### *2.2. Population*

# %%
# Import csv population de 2000 à 2018
# Source : OCR
data_population = pd.read_csv('Population_2000_2018.csv')
data_population
# Out:
#      Code Domaine                       Domaine  Code zone         Zone  \
# 0              OA  Séries temporelles annuelles          2  Afghanistan
# 1              OA  Séries temporelles annuelles          2  Afghanistan
# 2              OA  Séries temporelles annuelles          2  Afghanistan
# 3              OA  Séries temporelles annuelles          2  Afghanistan
# 4              OA  Séries temporelles annuelles          2  Afghanistan
# ...           ...                           ...        ...          ...
# 4406           OA  Séries temporelles annuelles        181     Zimbabwe
# 4407           OA  Séries temporelles annuelles        181     Zimbabwe
# 4408           OA  Séries temporelles annuelles        181     Zimbabwe
# 4409           OA  Séries temporelles annuelles        181     Zimbabwe
# 4410           OA  Séries temporelles annuelles        181     Zimbabwe
#
#       Code Élément            Élément  Code Produit                 Produit  \
# 0              511  Population totale          3010  Population-Estimations
# 1              511  Population totale          3010  Population-Estimations
# 2              511  Population totale          3010  Population-Estimations
# 3              511  Population totale          3010  Population-Estimations
# 4              511  Population totale          3010  Population-Estimations
# ...            ...                ...           ...                     ...
# 4406           511  Population totale          3010  Population-Estimations
# 4407           511  Population totale          3010  Population-Estimations
# 4408           511  Population totale          3010  Population-Estimations
# 4409           511  Population totale          3010  Population-Estimations
# 4410           511  Population totale          3010  Population-Estimations
#
#       Code année  Année           Unité     Valeur Symbole  \
# 0           2000   2000  1000 personnes  20779.953       X
# 1           2001   2001  1000 personnes  21606.988       X
# 2           2002   2002  1000 personnes  22600.770       X
# 3           2003   2003  1000 personnes  23680.871       X
# 4           2004   2004  1000 personnes  24726.684       X
# ...          ...    ...             ...        ...     ...
# 4406        2014   2014  1000 personnes  13586.707       X
# 4407        2015   2015  1000 personnes  13814.629       X
# 4408        2016   2016  1000 personnes  14030.331       X
# 4409        2017   2017  1000 personnes  14236.595       X
# 4410        2018   2018  1000 personnes  14438.802       X
#
#              Description du Symbole Note
# 0     Sources internationales sûres  NaN
# 1     Sources internationales sûres  NaN
# 2     Sources internationales sûres  NaN
# 3     Sources internationales sûres  NaN
# 4     Sources internationales sûres  NaN
# ...                             ...  ...
# 4406  Sources internationales sûres  NaN
# 4407  Sources internationales sûres  NaN
# 4408  Sources internationales sûres  NaN
# 4409  Sources internationales sûres  NaN
# 4410  Sources internationales sûres  NaN
#
# [4411 rows x 15 columns]

# %%
# Info sur le dataset
data_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4411 entries, 0 to 4410
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            4411 non-null   object
#  1   Domaine                 4411 non-null   object
#  2   Code zone               4411 non-null   int64
#  3   Zone                    4411 non-null   object
#  4   Code Élément            4411 non-null   int64
#  5   Élément                 4411 non-null   object
#  6   Code Produit            4411 non-null   int64
#  7   Produit                 4411 non-null   object
#  8   Code année              4411 non-null   int64
#  9   Année                   4411 non-null   int64
#  10  Unité                   4411 non-null   object
#  11  Valeur                  4411 non-null   float64
#  12  Symbole                 4411 non-null   object
#  13  Description du Symbole  4411 non-null   object
#  14  Note                    258 non-null    object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 517.0+ KB

# %%
# Recherche de manquants
# On voit qu'il y a bcp de manquants dans 'Note', on ne s'en occupe pas car cette colonne sera supprimée
data_population.isna().sum()
# Out:
# Code Domaine                 0
# Domaine                      0
# Code zone                    0
# Zone                         0
# Code Élément                 0
# Élément                      0
# Code Produit                 0
# Produit                      0
# Code année                   0
# Année                        0
# Unité                        0
# Valeur                       0
# Symbole                      0
# Description du Symbole       0
# Note                      4153
# dtype: int64

# %%
# Describe sur le dataset
# L'étendue des données va de 2000 à 2018
# Note : On a 238 pays
data_population.describe(include = 'all')
# Out:
#        Code Domaine                       Domaine    Code zone         Zone  \
# count          4411                          4411  4411.000000         4411
# unique            1                             1          NaN          238
# top              OA  Séries temporelles annuelles          NaN  Afghanistan
# freq           4411                          4411          NaN           19
# mean            NaN                           NaN   132.202902          NaN
# std             NaN                           NaN    75.854840          NaN
# min             NaN                           NaN     1.000000          NaN
# 25%             NaN                           NaN    68.000000          NaN
# 50%             NaN                           NaN   132.000000          NaN
# 75%             NaN                           NaN   195.000000          NaN
# max             NaN                           NaN   299.000000          NaN
#
#         Code Élément            Élément  Code Produit                 Produit  \
# count         4411.0               4411        4411.0                    4411
# unique           NaN                  1           NaN                       1
# top              NaN  Population totale           NaN  Population-Estimations
# freq             NaN               4411           NaN                    4411
# mean           511.0                NaN        3010.0                     NaN
# std              0.0                NaN           0.0                     NaN
# min            511.0                NaN        3010.0                     NaN
# 25%            511.0                NaN        3010.0                     NaN
# 50%            511.0                NaN        3010.0                     NaN
# 75%            511.0                NaN        3010.0                     NaN
# max            511.0                NaN        3010.0                     NaN
#
#          Code année        Année           Unité        Valeur Symbole  \
# count   4411.000000  4411.000000            4411  4.411000e+03    4411
# unique          NaN          NaN               1           NaN       2
# top             NaN          NaN  1000 personnes           NaN       X
# freq            NaN          NaN            4411           NaN    4374
# mean    2009.068238  2009.068238             NaN  2.963004e+04     NaN
# std        5.481539     5.481539             NaN  1.238029e+05     NaN
# min     2000.000000  2000.000000             NaN  7.850000e-01     NaN
# 25%     2004.000000  2004.000000             NaN  3.921890e+02     NaN
# 50%     2009.000000  2009.000000             NaN  4.764741e+03     NaN
# 75%     2014.000000  2014.000000             NaN  1.821548e+04     NaN
# max     2018.000000  2018.000000             NaN  1.427648e+06     NaN
#
#                Description du Symbole  \
# count                            4411
# unique                              2
# top     Sources internationales sûres
# freq                             4374
# mean                              NaN
# std                               NaN
# min                               NaN
# 25%                               NaN
# 50%                               NaN
# 75%                               NaN
# max                               NaN
#
#                                                      Note
# count                                                 258
# unique                                                  1
# top     UNDESA, Population Division – World Population...
# freq                                                  258
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# Mapping des colonnes
# On récupère l'entête sous forme de liste
col_df = list(data_population.columns)
# On défini les valeurs de remplacement
col_replace = ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# En premier les éléments à remplacer, en second la valeur de remplacement
replace_dict = dict(zip(col_df, col_replace)) # Mise des données sous  forme de dico
print(replace_dict)
# On passe le dico créé dans le rename
data_population = data_population.rename(columns = replace_dict)

data_population
# Out:
# {'Code Domaine': 'domain_code', 'Domaine': 'domaine', 'Code zone': 'zone_code', 'Zone': 'zone', 'Code Élément': 'item_code', 'Élément': 'item', 'Code Produit': 'product_code', 'Produit': 'product', 'Code année': 'year_code', 'Année': 'year', 'Unité': 'unity', 'Valeur': 'value', 'Symbole': 'symbole', 'Description du Symbole': 'symbole_descr'}
#      domain_code                       domaine  zone_code         zone  \
# 0             OA  Séries temporelles annuelles          2  Afghanistan
# 1             OA  Séries temporelles annuelles          2  Afghanistan
# 2             OA  Séries temporelles annuelles          2  Afghanistan
# 3             OA  Séries temporelles annuelles          2  Afghanistan
# 4             OA  Séries temporelles annuelles          2  Afghanistan
# ...          ...                           ...        ...          ...
# 4406          OA  Séries temporelles annuelles        181     Zimbabwe
# 4407          OA  Séries temporelles annuelles        181     Zimbabwe
# 4408          OA  Séries temporelles annuelles        181     Zimbabwe
# 4409          OA  Séries temporelles annuelles        181     Zimbabwe
# 4410          OA  Séries temporelles annuelles        181     Zimbabwe
#
#       item_code               item  product_code                 product  \
# 0           511  Population totale          3010  Population-Estimations
# 1           511  Population totale          3010  Population-Estimations
# 2           511  Population totale          3010  Population-Estimations
# 3           511  Population totale          3010  Population-Estimations
# 4           511  Population totale          3010  Population-Estimations
# ...         ...                ...           ...                     ...
# 4406        511  Population totale          3010  Population-Estimations
# 4407        511  Population totale          3010  Population-Estimations
# 4408        511  Population totale          3010  Population-Estimations
# 4409        511  Population totale          3010  Population-Estimations
# 4410        511  Population totale          3010  Population-Estimations
#
#       year_code  year           unity      value symbole  \
# 0          2000  2000  1000 personnes  20779.953       X
# 1          2001  2001  1000 personnes  21606.988       X
# 2          2002  2002  1000 personnes  22600.770       X
# 3          2003  2003  1000 personnes  23680.871       X
# 4          2004  2004  1000 personnes  24726.684       X
# ...         ...   ...             ...        ...     ...
# 4406       2014  2014  1000 personnes  13586.707       X
# 4407       2015  2015  1000 personnes  13814.629       X
# 4408       2016  2016  1000 personnes  14030.331       X
# 4409       2017  2017  1000 personnes  14236.595       X
# 4410       2018  2018  1000 personnes  14438.802       X
#
#                       symbole_descr Note
# 0     Sources internationales sûres  NaN
# 1     Sources internationales sûres  NaN
# 2     Sources internationales sûres  NaN
# 3     Sources internationales sûres  NaN
# 4     Sources internationales sûres  NaN
# ...                             ...  ...
# 4406  Sources internationales sûres  NaN
# 4407  Sources internationales sûres  NaN
# 4408  Sources internationales sûres  NaN
# 4409  Sources internationales sûres  NaN
# 4410  Sources internationales sûres  NaN
#
# [4411 rows x 15 columns]

# %%
# On regarde vite fait ce qui n'est pas NaN dans 'Note'
# On drop les NaN de cette colonne pour voir les données contenue dedans
data_population.dropna(subset = 'Note').head()
# Out:
#    domain_code                       domaine  zone_code     zone  item_code  \
# 95          OA  Séries temporelles annuelles          6  Andorre        511
# 96          OA  Séries temporelles annuelles          6  Andorre        511
# 97          OA  Séries temporelles annuelles          6  Andorre        511
# 98          OA  Séries temporelles annuelles          6  Andorre        511
# 99          OA  Séries temporelles annuelles          6  Andorre        511
#
#                  item  product_code                 product  year_code  year  \
# 95  Population totale          3010  Population-Estimations       2000  2000
# 96  Population totale          3010  Population-Estimations       2001  2001
# 97  Population totale          3010  Population-Estimations       2002  2002
# 98  Population totale          3010  Population-Estimations       2003  2003
# 99  Population totale          3010  Population-Estimations       2004  2004
#
#              unity   value symbole                  symbole_descr  \
# 95  1000 personnes  65.390       X  Sources internationales sûres
# 96  1000 personnes  67.341       X  Sources internationales sûres
# 97  1000 personnes  70.049       X  Sources internationales sûres
# 98  1000 personnes  73.182       X  Sources internationales sûres
# 99  1000 personnes  76.244       X  Sources internationales sûres
#
#                                                  Note
# 95  UNDESA, Population Division – World Population...
# 96  UNDESA, Population Division – World Population...
# 97  UNDESA, Population Division – World Population...
# 98  UNDESA, Population Division – World Population...
# 99  UNDESA, Population Division – World Population...

# %%
# Sélection de deux années pour calculer l'évolutionde la population et être raccord rapport au dataset dispo alim
# On prendra une évolution de la population sur les 10 dernières années en calant la dernière année sur l'année de nos données de dispo
# On rest l'index pour que ce soit propre
df_population = data_population.loc[(data_population['year'] == 2007) | (data_population['year'] == 2017)].reset_index(drop = True).copy()
df_population
# Out:
#     domain_code                       domaine  zone_code            zone  \
# 0            OA  Séries temporelles annuelles          2     Afghanistan
# 1            OA  Séries temporelles annuelles          2     Afghanistan
# 2            OA  Séries temporelles annuelles        202  Afrique du Sud
# 3            OA  Séries temporelles annuelles        202  Afrique du Sud
# 4            OA  Séries temporelles annuelles          3         Albanie
# ..          ...                           ...        ...             ...
# 461          OA  Séries temporelles annuelles        249           Yémen
# 462          OA  Séries temporelles annuelles        251          Zambie
# 463          OA  Séries temporelles annuelles        251          Zambie
# 464          OA  Séries temporelles annuelles        181        Zimbabwe
# 465          OA  Séries temporelles annuelles        181        Zimbabwe
#
#      item_code               item  product_code                 product  \
# 0          511  Population totale          3010  Population-Estimations
# 1          511  Population totale          3010  Population-Estimations
# 2          511  Population totale          3010  Population-Estimations
# 3          511  Population totale          3010  Population-Estimations
# 4          511  Population totale          3010  Population-Estimations
# ..         ...                ...           ...                     ...
# 461        511  Population totale          3010  Population-Estimations
# 462        511  Population totale          3010  Population-Estimations
# 463        511  Population totale          3010  Population-Estimations
# 464        511  Population totale          3010  Population-Estimations
# 465        511  Population totale          3010  Population-Estimations
#
#      year_code  year           unity      value symbole  \
# 0         2007  2007  1000 personnes  27100.536       X
# 1         2017  2017  1000 personnes  36296.113       X
# 2         2007  2007  1000 personnes  49119.759       X
# 3         2017  2017  1000 personnes  57009.756       X
# 4         2007  2007  1000 personnes   3033.998       X
# ..         ...   ...             ...        ...     ...
# 461       2017  2017  1000 personnes  27834.819       X
# 462       2007  2007  1000 personnes  12502.958       X
# 463       2017  2017  1000 personnes  16853.599       X
# 464       2007  2007  1000 personnes  12255.922       X
# 465       2017  2017  1000 personnes  14236.595       X
#
#                      symbole_descr Note
# 0    Sources internationales sûres  NaN
# 1    Sources internationales sûres  NaN
# 2    Sources internationales sûres  NaN
# 3    Sources internationales sûres  NaN
# 4    Sources internationales sûres  NaN
# ..                             ...  ...
# 461  Sources internationales sûres  NaN
# 462  Sources internationales sûres  NaN
# 463  Sources internationales sûres  NaN
# 464  Sources internationales sûres  NaN
# 465  Sources internationales sûres  NaN
#
# [466 rows x 15 columns]

# %%
# Est ce que l'on compare les pays entre les deux dataset et on ne garde que ceux qui sont dans la dispo ?

# %%
print('Nombre de pays dans population :', len(df_population['zone'].unique()))
print('Nombre de pays dans dispo_alim :', len(df_dispo_alim['zone'].unique()))
# Out:
# Nombre de pays dans population : 237
# Nombre de pays dans dispo_alim : 174

# %%
# On fait un mask avec les pays présents dans le df_dispo_alim pour faire un filtre sur le df_population afin de limiter dans un premier temps les données manquantes
print(len(df_dispo_alim['zone'].unique()))
mask = df_dispo_alim['zone'].unique().tolist()
mask[:5]
# Out:
# 174
# ['Afghanistan', 'Afrique du Sud', 'Albanie', 'Algérie', 'Allemagne']

# %%
# Pour simplifier on ne prend que les pays qui sont présents dans le df_dispo_alim, cela évitera d'avoir certains pays sans aucune données autre que la population àgérer plus tard
# Donc ces pays ne sont pas intéressants pour notre étude
df_population = df_population.loc[df_population['zone'].isin(mask)].copy()
df_population
# Out:
#     domain_code                       domaine  zone_code            zone  \
# 0            OA  Séries temporelles annuelles          2     Afghanistan
# 1            OA  Séries temporelles annuelles          2     Afghanistan
# 2            OA  Séries temporelles annuelles        202  Afrique du Sud
# 3            OA  Séries temporelles annuelles        202  Afrique du Sud
# 4            OA  Séries temporelles annuelles          3         Albanie
# ..          ...                           ...        ...             ...
# 461          OA  Séries temporelles annuelles        249           Yémen
# 462          OA  Séries temporelles annuelles        251          Zambie
# 463          OA  Séries temporelles annuelles        251          Zambie
# 464          OA  Séries temporelles annuelles        181        Zimbabwe
# 465          OA  Séries temporelles annuelles        181        Zimbabwe
#
#      item_code               item  product_code                 product  \
# 0          511  Population totale          3010  Population-Estimations
# 1          511  Population totale          3010  Population-Estimations
# 2          511  Population totale          3010  Population-Estimations
# 3          511  Population totale          3010  Population-Estimations
# 4          511  Population totale          3010  Population-Estimations
# ..         ...                ...           ...                     ...
# 461        511  Population totale          3010  Population-Estimations
# 462        511  Population totale          3010  Population-Estimations
# 463        511  Population totale          3010  Population-Estimations
# 464        511  Population totale          3010  Population-Estimations
# 465        511  Population totale          3010  Population-Estimations
#
#      year_code  year           unity      value symbole  \
# 0         2007  2007  1000 personnes  27100.536       X
# 1         2017  2017  1000 personnes  36296.113       X
# 2         2007  2007  1000 personnes  49119.759       X
# 3         2017  2017  1000 personnes  57009.756       X
# 4         2007  2007  1000 personnes   3033.998       X
# ..         ...   ...             ...        ...     ...
# 461       2017  2017  1000 personnes  27834.819       X
# 462       2007  2007  1000 personnes  12502.958       X
# 463       2017  2017  1000 personnes  16853.599       X
# 464       2007  2007  1000 personnes  12255.922       X
# 465       2017  2017  1000 personnes  14236.595       X
#
#                      symbole_descr Note
# 0    Sources internationales sûres  NaN
# 1    Sources internationales sûres  NaN
# 2    Sources internationales sûres  NaN
# 3    Sources internationales sûres  NaN
# 4    Sources internationales sûres  NaN
# ..                             ...  ...
# 461  Sources internationales sûres  NaN
# 462  Sources internationales sûres  NaN
# 463  Sources internationales sûres  NaN
# 464  Sources internationales sûres  NaN
# 465  Sources internationales sûres  NaN
#
# [347 rows x 15 columns]

# %%
# On vérifie que le nombre de pays correspondent
print('Nombre de pays dans population :', len(df_population['zone'].unique()))
print('Nombre de pays dans dispo_alim :', len(df_dispo_alim['zone'].unique()))
# Out:
# Nombre de pays dans population : 174
# Nombre de pays dans dispo_alim : 174

# %%
# Vérifier le nombre de pays qui correspondent

# %%
# En dernier un reset_index du df
df_population.reset_index(drop = True, inplace = True)

# %% [markdown]
# #### *2.3. PIB*

# %%
# Import csv PIB de 2007 à 2017
# Source : FAO
data_pib = pd.read_csv('PIB.csv')
data_pib
# Out:
#      Code Domaine            Domaine  Code zone (M49)                    Zone  \
# 0              MK  Indicateurs macro              528  Pays-Bas (Royaume des)
# 1              MK  Indicateurs macro              528  Pays-Bas (Royaume des)
# 2              MK  Indicateurs macro              528  Pays-Bas (Royaume des)
# 3              MK  Indicateurs macro              528  Pays-Bas (Royaume des)
# 4              MK  Indicateurs macro              528  Pays-Bas (Royaume des)
# ...           ...                ...              ...                     ...
# 9295           MK  Indicateurs macro              716                Zimbabwe
# 9296           MK  Indicateurs macro              716                Zimbabwe
# 9297           MK  Indicateurs macro              716                Zimbabwe
# 9298           MK  Indicateurs macro              716                Zimbabwe
# 9299           MK  Indicateurs macro              716                Zimbabwe
#
#       Code Élément                               Élément  Code Produit  \
# 0             6110                           Valeur US $         22008
# 1             6119              Valeur US $ par habitant         22008
# 2             6129               Croissance annuelle US$         22008
# 3            61290  Croissance annuelle US$ par habitant         22008
# 4             6110                           Valeur US $         22008
# ...            ...                                   ...           ...
# 9295         61290  Croissance annuelle US$ par habitant         22008
# 9296          6110                           Valeur US $         22008
# 9297          6119              Valeur US $ par habitant         22008
# 9298          6129               Croissance annuelle US$         22008
# 9299         61290  Croissance annuelle US$ par habitant         22008
#
#                      Produit  Code année  Année           Unité  \
# 0     Produit Intérieur Brut        2007   2007  Millions d’USD
# 1     Produit Intérieur Brut        2007   2007             US$
# 2     Produit Intérieur Brut        2007   2007               %
# 3     Produit Intérieur Brut        2007   2007               %
# 4     Produit Intérieur Brut        2008   2008  Millions d’USD
# ...                      ...         ...    ...             ...
# 9295  Produit Intérieur Brut        2016   2016               %
# 9296  Produit Intérieur Brut        2017   2017  Millions d’USD
# 9297  Produit Intérieur Brut        2017   2017             US$
# 9298  Produit Intérieur Brut        2017   2017               %
# 9299  Produit Intérieur Brut        2017   2017               %
#
#              Valeur Symbole             Description du Symbole  Note
# 0     847438.025000       X  Ciffre de sources internationales   NaN
# 1      51700.691260       X  Ciffre de sources internationales   NaN
# 2         15.564464       X  Ciffre de sources internationales   NaN
# 3         15.102276       X  Ciffre de sources internationales   NaN
# 4     948032.773700       X  Ciffre de sources internationales   NaN
# ...             ...     ...                                ...   ...
# 9295       0.812478       X  Ciffre de sources internationales   NaN
# 9296   22040.654700       X  Ciffre de sources internationales   NaN
# 9297    1494.170144       X  Ciffre de sources internationales   NaN
# 9298       7.260694       X  Ciffre de sources internationales   NaN
# 9299       5.090939       X  Ciffre de sources internationales   NaN
#
# [9300 rows x 15 columns]

# %%
# Mapping des colonnes
# On récupère l'entête sous forme de liste
col_df = list(data_pib.columns)
# On défini les valeurs de remplacement
col_replace = ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# En premier les éléments à remplacer, en second la valeur de remplacement
replace_dict = dict(zip(col_df, col_replace)) # Mise des données sous  forme de dico
print(replace_dict)
# On passe le dico créé dans le rename
data_pib = data_pib.rename(columns = replace_dict)

data_pib.head()
# Out:
# {'Code Domaine': 'domain_code', 'Domaine': 'domaine', 'Code zone (M49)': 'zone_code', 'Zone': 'zone', 'Code Élément': 'item_code', 'Élément': 'item', 'Code Produit': 'product_code', 'Produit': 'product', 'Code année': 'year_code', 'Année': 'year', 'Unité': 'unity', 'Valeur': 'value', 'Symbole': 'symbole', 'Description du Symbole': 'symbole_descr'}
#   domain_code            domaine  zone_code                    zone  \
# 0          MK  Indicateurs macro        528  Pays-Bas (Royaume des)
# 1          MK  Indicateurs macro        528  Pays-Bas (Royaume des)
# 2          MK  Indicateurs macro        528  Pays-Bas (Royaume des)
# 3          MK  Indicateurs macro        528  Pays-Bas (Royaume des)
# 4          MK  Indicateurs macro        528  Pays-Bas (Royaume des)
#
#    item_code                                  item  product_code  \
# 0       6110                           Valeur US $         22008
# 1       6119              Valeur US $ par habitant         22008
# 2       6129               Croissance annuelle US$         22008
# 3      61290  Croissance annuelle US$ par habitant         22008
# 4       6110                           Valeur US $         22008
#
#                   product  year_code  year           unity          value  \
# 0  Produit Intérieur Brut       2007  2007  Millions d’USD  847438.025000
# 1  Produit Intérieur Brut       2007  2007             US$   51700.691260
# 2  Produit Intérieur Brut       2007  2007               %      15.564464
# 3  Produit Intérieur Brut       2007  2007               %      15.102276
# 4  Produit Intérieur Brut       2008  2008  Millions d’USD  948032.773700
#
#   symbole                      symbole_descr  Note
# 0       X  Ciffre de sources internationales   NaN
# 1       X  Ciffre de sources internationales   NaN
# 2       X  Ciffre de sources internationales   NaN
# 3       X  Ciffre de sources internationales   NaN
# 4       X  Ciffre de sources internationales   NaN

# %%
data_pib.describe()
# Out:
#          zone_code     item_code  product_code    year_code         year  \
# count  9300.000000   9300.000000        9300.0  9300.000000  9300.000000
# mean    429.413118  19906.065591       22008.0  2011.997419  2011.997419
# std     250.342053  23887.459876           0.0     3.160678     3.160678
# min       4.000000   6110.000000       22008.0  2007.000000  2007.000000
# 25%     208.000000   6110.000000       22008.0  2009.000000  2009.000000
# 50%     430.000000   6119.000000       22008.0  2012.000000  2012.000000
# 75%     642.000000   6129.000000       22008.0  2015.000000  2015.000000
# max     894.000000  61290.000000       22008.0  2017.000000  2017.000000
#
#               value  Note
# count  9.300000e+03   0.0
# mean   9.849497e+04   NaN
# std    7.768514e+05   NaN
# min   -5.830523e+01   NaN
# 25%    5.045603e+00   NaN
# 50%    4.978308e+01   NaN
# 75%    1.127283e+04   NaN
# max    1.947734e+07   NaN

# %%
# Iln'y a pas de valeurs manquantes
data_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9300 entries, 0 to 9299
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   domain_code    9300 non-null   object
#  1   domaine        9300 non-null   object
#  2   zone_code      9300 non-null   int64
#  3   zone           9300 non-null   object
#  4   item_code      9300 non-null   int64
#  5   item           9300 non-null   object
#  6   product_code   9300 non-null   int64
#  7   product        9300 non-null   object
#  8   year_code      9300 non-null   int64
#  9   year           9300 non-null   int64
#  10  unity          9300 non-null   object
#  11  value          9300 non-null   float64
#  12  symbole        9300 non-null   object
#  13  symbole_descr  9300 non-null   object
#  14  Note           0 non-null      float64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 1.1+ MB

# %%
# Sélection de deux années pour calculer l'évolution du pib et être raccord rapport au dataset dispo alim
# On prendra les 10 dernières années en calant la dernière année sur l'année de nos données de dispo
# Egalement, on ne prendre que la valeur du PIB pour calculer l'évolution entre ces deux années (idem que pour la population)
df_pib = data_pib.loc[(data_pib['year'] == 2007) | (data_pib['year'] == 2017)]
# On prend la valeur du PIB globale pour calculer l'évolution sur 2007 - 2017, on reset l'index pour que ce soit propre
df_pib = df_pib.loc[df_pib['item'] == 'Valeur US $'].copy().reset_index(drop = True).copy()
df_pib
# Out:
#     domain_code            domaine  zone_code                    zone  \
# 0            MK  Indicateurs macro        528  Pays-Bas (Royaume des)
# 1            MK  Indicateurs macro        528  Pays-Bas (Royaume des)
# 2            MK  Indicateurs macro          4             Afghanistan
# 3            MK  Indicateurs macro          4             Afghanistan
# 4            MK  Indicateurs macro        710          Afrique du Sud
# ..          ...                ...        ...                     ...
# 417          MK  Indicateurs macro        887                   Yémen
# 418          MK  Indicateurs macro        894                  Zambie
# 419          MK  Indicateurs macro        894                  Zambie
# 420          MK  Indicateurs macro        716                Zimbabwe
# 421          MK  Indicateurs macro        716                Zimbabwe
#
#      item_code         item  product_code                 product  year_code  \
# 0         6110  Valeur US $         22008  Produit Intérieur Brut       2007
# 1         6110  Valeur US $         22008  Produit Intérieur Brut       2017
# 2         6110  Valeur US $         22008  Produit Intérieur Brut       2007
# 3         6110  Valeur US $         22008  Produit Intérieur Brut       2017
# 4         6110  Valeur US $         22008  Produit Intérieur Brut       2007
# ..         ...          ...           ...                     ...        ...
# 417       6110  Valeur US $         22008  Produit Intérieur Brut       2017
# 418       6110  Valeur US $         22008  Produit Intérieur Brut       2007
# 419       6110  Valeur US $         22008  Produit Intérieur Brut       2017
# 420       6110  Valeur US $         22008  Produit Intérieur Brut       2007
# 421       6110  Valeur US $         22008  Produit Intérieur Brut       2017
#
#      year           unity          value symbole  \
# 0    2007  Millions d’USD  847438.025000       X
# 1    2017  Millions d’USD  833869.641700       X
# 2    2007  Millions d’USD    9412.161765       X
# 3    2017  Millions d’USD   18896.352020       X
# 4    2007  Millions d’USD  333077.117200       X
# ..    ...             ...            ...     ...
# 417  2017  Millions d’USD   18391.649820       X
# 418  2007  Millions d’USD   14056.884800       X
# 419  2017  Millions d’USD   25868.161490       X
# 420  2007  Millions d’USD    6958.294807       X
# 421  2017  Millions d’USD   22040.654700       X
#
#                          symbole_descr  Note
# 0    Ciffre de sources internationales   NaN
# 1    Ciffre de sources internationales   NaN
# 2    Ciffre de sources internationales   NaN
# 3    Ciffre de sources internationales   NaN
# 4    Ciffre de sources internationales   NaN
# ..                                 ...   ...
# 417  Ciffre de sources internationales   NaN
# 418  Ciffre de sources internationales   NaN
# 419  Ciffre de sources internationales   NaN
# 420  Ciffre de sources internationales   NaN
# 421  Ciffre de sources internationales   NaN
#
# [422 rows x 15 columns]

# %% [markdown]
# ---
# # ***--- A voir ---***

# %%
# On regarde le nombre de pays unique dans chaque df
print('Nombre de pays dans dispo_alim :', len(df_dispo_alim['zone'].unique()))
print('Nombre de pays dans df_pib :', len(df_pib['zone'].unique()))
# Out:
# Nombre de pays dans dispo_alim : 174
# Nombre de pays dans df_pib : 213

# %%
# Faire fonction pour trouver les pays qui ne correspondent pas
# Sortir la colonne pays de chaque df, les merges et voir ou ça ne colle pas avec indicator True ? Récup deux list et en faire un dico de remplacement ?

# %%
# Une piste avec un isin entre les deux, on regarde tout les pays de pib qui ne sont pas dans dispo_alim
# Nombre de pays dans df_pib qui ne sont pas dans df_dispo_alim
print('Nombre de pays dans df_pib non présents dans df_dispo_alim :', len(df_pib.loc[~df_pib['zone'].isin(df_dispo_alim['zone'])]))
# Out:
# Nombre de pays dans df_pib non présents dans df_dispo_alim : 79

# %%
# Deux pays qui possaient soucis : Pays-Bas et Chine, Taiwan Province de
# Je l'ai repéré après sélection des features plus loin, voir si possible de les détecter à ce niveau
# C'est juste une question d'appellation des pays dans les dataset fournis qui ne sont pas de la même source...

# %%
# Je veux une liste des pays contenant pays bas dans data_pib
a = data_pib.loc[data_pib['zone'].str.contains('Pays')]
print(a['zone'].unique().tolist())
# Je veux une liste des pays contenant pays bas dans df_dispo
b = df_dispo_alim.loc[df_dispo_alim['zone'].str.contains('Pays')]
print(b['zone'].unique().tolist())
# Out:
# ['Pays-Bas (Royaume des)']
# ['Pays-Bas']

# %%
# Je veux une liste des pays contenant chine dans data_pib
a = data_pib.loc[data_pib['zone'].str.contains('Chine')]
print(a['zone'].unique().tolist())
# Je veux une liste des pays contenant chine dans df_dispo
b = df_dispo_alim.loc[df_dispo_alim['zone'].str.contains('Chine')]
print(b['zone'].unique().tolist())
# Out:
# ['Chine', 'Chine - RAS de Hong-Kong', 'Chine - RAS de Macao', 'Chine, continentale']
# ['Chine - RAS de Hong-Kong', 'Chine - RAS de Macao', 'Chine, continentale', 'Chine, Taiwan Province de']

# %%
# Modification du nom de ces deux pays dans le df_pib
df_pib['zone'] = df_pib['zone'].replace({'Pays-Bas (Royaume des)' : 'Pays-Bas', 'Chine' : 'Chine, Taiwan Province de'}).copy()

# %% [markdown]
# # ***--- Fin à voir ---***
# ---

# %%
# Sélection des pays
# On fait un mask avec les pays présents dans le df_dispo_alim pour faire un filtre sur le df_pib afin de limiter dans un premier temps les données manquantes
print('Nombre de pays dans df_dispo_alim :', len(df_dispo_alim['zone'].unique()))
mask = df_dispo_alim['zone'].unique().tolist()
mask[:5]
# Out:
# Nombre de pays dans df_dispo_alim : 174
# ['Afghanistan', 'Afrique du Sud', 'Albanie', 'Algérie', 'Allemagne']

# %%
# Pour simplifier on ne prend que les pays qui sont présents dans le df_dispo_alim, cela évitera d'avoir certains pays sans aucune données autre que la population àgérer plus tard
# Donc ces pays ne sont pas intéressants pour notre étude
df_pib = df_pib.loc[df_pib['zone'].isin(mask)].copy()
df_pib
# Out:
#     domain_code            domaine  zone_code            zone  item_code  \
# 0            MK  Indicateurs macro        528        Pays-Bas       6110
# 1            MK  Indicateurs macro        528        Pays-Bas       6110
# 2            MK  Indicateurs macro          4     Afghanistan       6110
# 3            MK  Indicateurs macro          4     Afghanistan       6110
# 4            MK  Indicateurs macro        710  Afrique du Sud       6110
# ..          ...                ...        ...             ...        ...
# 417          MK  Indicateurs macro        887           Yémen       6110
# 418          MK  Indicateurs macro        894          Zambie       6110
# 419          MK  Indicateurs macro        894          Zambie       6110
# 420          MK  Indicateurs macro        716        Zimbabwe       6110
# 421          MK  Indicateurs macro        716        Zimbabwe       6110
#
#             item  product_code                 product  year_code  year  \
# 0    Valeur US $         22008  Produit Intérieur Brut       2007  2007
# 1    Valeur US $         22008  Produit Intérieur Brut       2017  2017
# 2    Valeur US $         22008  Produit Intérieur Brut       2007  2007
# 3    Valeur US $         22008  Produit Intérieur Brut       2017  2017
# 4    Valeur US $         22008  Produit Intérieur Brut       2007  2007
# ..           ...           ...                     ...        ...   ...
# 417  Valeur US $         22008  Produit Intérieur Brut       2017  2017
# 418  Valeur US $         22008  Produit Intérieur Brut       2007  2007
# 419  Valeur US $         22008  Produit Intérieur Brut       2017  2017
# 420  Valeur US $         22008  Produit Intérieur Brut       2007  2007
# 421  Valeur US $         22008  Produit Intérieur Brut       2017  2017
#
#               unity          value symbole                      symbole_descr  \
# 0    Millions d’USD  847438.025000       X  Ciffre de sources internationales
# 1    Millions d’USD  833869.641700       X  Ciffre de sources internationales
# 2    Millions d’USD    9412.161765       X  Ciffre de sources internationales
# 3    Millions d’USD   18896.352020       X  Ciffre de sources internationales
# 4    Millions d’USD  333077.117200       X  Ciffre de sources internationales
# ..              ...            ...     ...                                ...
# 417  Millions d’USD   18391.649820       X  Ciffre de sources internationales
# 418  Millions d’USD   14056.884800       X  Ciffre de sources internationales
# 419  Millions d’USD   25868.161490       X  Ciffre de sources internationales
# 420  Millions d’USD    6958.294807       X  Ciffre de sources internationales
# 421  Millions d’USD   22040.654700       X  Ciffre de sources internationales
#
#      Note
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 417   NaN
# 418   NaN
# 419   NaN
# 420   NaN
# 421   NaN
#
# [347 rows x 15 columns]

# %%
# On vérifie après correction
print('Nombre de pays dans dispo_alim :', len(df_dispo_alim['zone'].unique()))
print('Nombre de pays dans df_pib :', len(df_pib['zone'].unique()))
# Out:
# Nombre de pays dans dispo_alim : 174
# Nombre de pays dans df_pib : 174

# %%
# Pays qui ne correspondent pas après préparation
print('Nombre de pays dans df_pib non présents dans df_dispo_alim :', len(df_pib.loc[~df_pib['zone'].isin(df_dispo_alim['zone'])]))
# Out:
# Nombre de pays dans df_pib non présents dans df_dispo_alim : 0

# %%
# En dernier on fait un reset_index
df_pib.reset_index(drop = True, inplace = True)

# %% [markdown]
# ---
# ## Partie 2 - Préparation des données finales

# %% [markdown]
# ### 3. Concaténation dataset global - Nettoyage - Préparation
# ---

# %% [markdown]
# #### *3. Vérification des entête*

# %%
# On vérifiela taille de nos df avant de les concatener

# %%
# Entre df_dispo et df_population
# On vérifie la correspondance des colonnes entre les deux df
print('Col data_dispo_alim :', df_dispo_alim.columns.tolist())
print('Col data_population :', df_population.columns.tolist())
# On compare les colonnes modifs
print('Les entêtes des deux dataset correspondent :', df_dispo_alim.columns.tolist() == df_population.columns.tolist())
# Out:
# Col data_dispo_alim : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# Col data_population : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr', 'Note']
# Les entêtes des deux dataset correspondent : False

# %%
# On remarque que data_population a une colonne en plus
# On supprime la colonne 'Note' de data_population pour que les deux df correspondent sur le nombre de colonnes (14 - 14)
df_population.drop(columns  = 'Note', inplace = True)

# %%
# On vérifie la correspondance des colonnes entre les deux df après modifs
print('Col data_dispo_alim :', df_dispo_alim.columns.tolist())
print('Col data_population :', df_population.columns.tolist())
# On compare les colonnes après modifs
print('Les entêtes des deux dataset correspondent :', df_dispo_alim.columns.tolist() == df_population.columns.tolist())
# Out:
# Col data_dispo_alim : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# Col data_population : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# Les entêtes des deux dataset correspondent : True

# %%
# Entre df_dispo et df_pib
# On vérifie la correspondance des colonnes entre les deux df
print('Col data_dispo_alim :', df_dispo_alim.columns.tolist())
print('Col data_population :', df_pib.columns.tolist())
# On compare les colonnes modifs
print('Les entêtes des deux dataset correspondent :', df_dispo_alim.columns.tolist() == df_pib.columns.tolist())
# Out:
# Col data_dispo_alim : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# Col data_population : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr', 'Note']
# Les entêtes des deux dataset correspondent : False

# %%
# On remarque que data_population a une colonne en plus
# On supprime la colonne 'Note' de data_population pour que les deux df correspondent sur le nombre de colonnes (14 - 14)
df_pib.drop(columns  = 'Note', inplace = True)

# %%
# On vérifie la correspondance des colonnes entre les deux df après modifs
print('Col data_dispo_alim :', df_dispo_alim.columns.tolist())
print('Col data_population :', df_pib.columns.tolist())
# On compare les colonnes après modifs
print('Les entêtes des deux dataset correspondent :', df_dispo_alim.columns.tolist() == df_pib.columns.tolist())
# Out:
# Col data_dispo_alim : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# Col data_population : ['domain_code', 'domaine', 'zone_code', 'zone', 'item_code', 'item', 'product_code', 'product', 'year_code', 'year', 'unity', 'value', 'symbole', 'symbole_descr']
# Les entêtes des deux dataset correspondent : True

# %% [markdown]
# #### *3. Concaténation des données*

# %%
# On concatène nos deux premiers dataset (dispo et population)
df_data = pd.concat([df_dispo_alim, df_population]) # Concaténation dispo alim et population
df_data
# Out:
#     domain_code                       domaine  zone_code         zone  \
# 0           FBS   Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 1           FBS   Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 2           FBS   Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 3           FBS   Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 4           FBS   Nouveaux Bilans Alimentaire        2.0  Afghanistan
# ..          ...                           ...        ...          ...
# 342          OA  Séries temporelles annuelles      249.0        Yémen
# 343          OA  Séries temporelles annuelles      251.0       Zambie
# 344          OA  Séries temporelles annuelles      251.0       Zambie
# 345          OA  Séries temporelles annuelles      181.0     Zimbabwe
# 346          OA  Séries temporelles annuelles      181.0     Zimbabwe
#
#      item_code                      item  product_code  \
# 0       5511.0                Production        2511.0
# 1       5611.0   Importations - Quantité        2511.0
# 2       5072.0        Variation de stock        2511.0
# 3       5911.0   Exportations - Quantité        2511.0
# 4       5301.0  Disponibilité intérieure        2511.0
# ..         ...                       ...           ...
# 342      511.0         Population totale        3010.0
# 343      511.0         Population totale        3010.0
# 344      511.0         Population totale        3010.0
# 345      511.0         Population totale        3010.0
# 346      511.0         Population totale        3010.0
#
#                     product  year_code    year               unity      value  \
# 0           Blé et produits     2017.0  2017.0  Milliers de tonnes   4281.000
# 1           Blé et produits     2017.0  2017.0  Milliers de tonnes   2302.000
# 2           Blé et produits     2017.0  2017.0  Milliers de tonnes   -119.000
# 3           Blé et produits     2017.0  2017.0  Milliers de tonnes      0.000
# 4           Blé et produits     2017.0  2017.0  Milliers de tonnes   6701.000
# ..                      ...        ...     ...                 ...        ...
# 342  Population-Estimations     2017.0  2017.0      1000 personnes  27834.819
# 343  Population-Estimations     2007.0  2007.0      1000 personnes  12502.958
# 344  Population-Estimations     2017.0  2017.0      1000 personnes  16853.599
# 345  Population-Estimations     2007.0  2007.0      1000 personnes  12255.922
# 346  Population-Estimations     2017.0  2017.0      1000 personnes  14236.595
#
#     symbole                  symbole_descr
# 0         S          Données standardisées
# 1         S          Données standardisées
# 2         S          Données standardisées
# 3         S          Données standardisées
# 4         S          Données standardisées
# ..      ...                            ...
# 342       X  Sources internationales sûres
# 343       X  Sources internationales sûres
# 344       X  Sources internationales sûres
# 345       X  Sources internationales sûres
# 346       X  Sources internationales sûres
#
# [179786 rows x 14 columns]

# %%
# # On concatène avec le dataset suivant, càd celui du PIB
df_data = pd.concat([df_data, df_pib])
df_data
# Out:
#     domain_code                      domaine  zone_code         zone  \
# 0           FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 1           FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 2           FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 3           FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 4           FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# ..          ...                          ...        ...          ...
# 342          MK            Indicateurs macro      887.0        Yémen
# 343          MK            Indicateurs macro      894.0       Zambie
# 344          MK            Indicateurs macro      894.0       Zambie
# 345          MK            Indicateurs macro      716.0     Zimbabwe
# 346          MK            Indicateurs macro      716.0     Zimbabwe
#
#      item_code                      item  product_code  \
# 0       5511.0                Production        2511.0
# 1       5611.0   Importations - Quantité        2511.0
# 2       5072.0        Variation de stock        2511.0
# 3       5911.0   Exportations - Quantité        2511.0
# 4       5301.0  Disponibilité intérieure        2511.0
# ..         ...                       ...           ...
# 342     6110.0               Valeur US $       22008.0
# 343     6110.0               Valeur US $       22008.0
# 344     6110.0               Valeur US $       22008.0
# 345     6110.0               Valeur US $       22008.0
# 346     6110.0               Valeur US $       22008.0
#
#                     product  year_code    year               unity  \
# 0           Blé et produits     2017.0  2017.0  Milliers de tonnes
# 1           Blé et produits     2017.0  2017.0  Milliers de tonnes
# 2           Blé et produits     2017.0  2017.0  Milliers de tonnes
# 3           Blé et produits     2017.0  2017.0  Milliers de tonnes
# 4           Blé et produits     2017.0  2017.0  Milliers de tonnes
# ..                      ...        ...     ...                 ...
# 342  Produit Intérieur Brut     2017.0  2017.0      Millions d’USD
# 343  Produit Intérieur Brut     2007.0  2007.0      Millions d’USD
# 344  Produit Intérieur Brut     2017.0  2017.0      Millions d’USD
# 345  Produit Intérieur Brut     2007.0  2007.0      Millions d’USD
# 346  Produit Intérieur Brut     2017.0  2017.0      Millions d’USD
#
#             value symbole                      symbole_descr
# 0     4281.000000       S              Données standardisées
# 1     2302.000000       S              Données standardisées
# 2     -119.000000       S              Données standardisées
# 3        0.000000       S              Données standardisées
# 4     6701.000000       S              Données standardisées
# ..            ...     ...                                ...
# 342  18391.649820       X  Ciffre de sources internationales
# 343  14056.884800       X  Ciffre de sources internationales
# 344  25868.161490       X  Ciffre de sources internationales
# 345   6958.294807       X  Ciffre de sources internationales
# 346  22040.654700       X  Ciffre de sources internationales
#
# [180133 rows x 14 columns]

# %%
# On reset l'index avant de passer à la suite
df_data.reset_index(drop = True, inplace = True)

# %% [markdown]
# #### *2.4. Sélection des données ('product')*

# %%
# On sélectionne les données qui nous intéressent pour cette analyse

# %%
# Liste des différents product dans nos données
print(df_data['product'].unique().tolist())
# Out:
# ['Blé et produits', 'Riz et produits', 'Orge et produits', 'Maïs et produits', 'Seigle et produits', 'Avoine', 'Millet et produits', 'Sorgho et produits', 'Céréales, Autres', 'Pommes de Terre et produits', 'Ignames', 'Racines nda', 'Sucre, canne', 'Sucre, betterave', 'Sucre Eq Brut', 'Edulcorants Autres', 'Miel', 'Haricots', 'Pois', 'Légumineuses Autres et produits', 'Noix et produits', 'Soja', 'Arachides Decortiquees', 'Graines de tournesol', 'Graines Colza/Moutarde', 'Graines de coton', 'Coco (Incl Coprah)', 'Sésame', 'Olives', 'Plantes Oleiferes, Autre', 'Huile de Soja', "Huile d'Arachide", 'Huile de Tournesol', 'Huile de Colza&Moutarde', 'Huile Graines de Coton', 'Huile de Palmistes', 'Huile de Palme', 'Huile de Coco', 'Huile de Sésame', "Huile d'Olive", 'Huile de Son de Riz', 'Huile de Germe de Maïs', 'Huil Plantes Oleif Autr', 'Tomates et produits', 'Oignons', 'Légumes, Autres', 'Oranges, Mandarines', 'Citrons & Limes et produits', 'Pamplemousse et produits', 'Agrumes, Autres', 'Bananes', 'Pommes et produits', 'Ananas et produits', 'Dattes', 'Raisin', 'Fruits, Autres', 'Café et produits', 'Feve de Cacao et produits', 'Thé', 'Poivre', 'Piments', 'Girofles', 'Épices, Autres', 'Vin', 'Bière', 'Boissons Fermentés', 'Boissons Alcooliques', 'Alcool, non Comestible', 'Viande de Bovins', "Viande d'Ovins/Caprins", 'Viande de Suides', 'Viande de Volailles', 'Viande, Autre', 'Abats Comestible', 'Beurre, Ghee', 'Crème', 'Graisses Animales Crue', 'Oeufs', 'Lait - Excl Beurre', 'Poissons Eau Douce', 'Aliments pour enfants', 'Miscellanees', 'Manioc et produits', 'Patates douces', 'Palmistes', 'Bananes plantains', 'Huiles de Poissons', 'Huiles de Foie de Poisso', 'Perciform', 'Poissons Pelagiques', 'Poissons Marins, Autres', 'Crustacés', 'Cephalopodes', 'Mollusques, Autres', 'Animaux Aquatiques Autre', 'Plantes Aquatiques', 'Sucre non centrifugé', 'Viande de Anim Aquatiq', 'Total', 'Population-Estimations', 'Produit Intérieur Brut']

# %%
# Sélection de ce qui nous intéresse
mask_final = ['Viande de Volailles', 'Total', 'Population-Estimations', 'Produit Intérieur Brut', 'Produit Intérieur Brut']
df_data_select = df_data.loc[df_data['product'].isin(mask_final)].copy()
df_data_select
# Out:
#        domain_code                      domaine  zone_code         zone  \
# 651            FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 652            FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 653            FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 654            FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# 655            FBS  Nouveaux Bilans Alimentaire        2.0  Afghanistan
# ...            ...                          ...        ...          ...
# 180128          MK            Indicateurs macro      887.0        Yémen
# 180129          MK            Indicateurs macro      894.0       Zambie
# 180130          MK            Indicateurs macro      894.0       Zambie
# 180131          MK            Indicateurs macro      716.0     Zimbabwe
# 180132          MK            Indicateurs macro      716.0     Zimbabwe
#
#         item_code                      item  product_code  \
# 651        5511.0                Production        2734.0
# 652        5611.0   Importations - Quantité        2734.0
# 653        5072.0        Variation de stock        2734.0
# 654        5301.0  Disponibilité intérieure        2734.0
# 655        5123.0                    Pertes        2734.0
# ...           ...                       ...           ...
# 180128     6110.0               Valeur US $       22008.0
# 180129     6110.0               Valeur US $       22008.0
# 180130     6110.0               Valeur US $       22008.0
# 180131     6110.0               Valeur US $       22008.0
# 180132     6110.0               Valeur US $       22008.0
#
#                        product  year_code    year               unity  \
# 651        Viande de Volailles     2017.0  2017.0  Milliers de tonnes
# 652        Viande de Volailles     2017.0  2017.0  Milliers de tonnes
# 653        Viande de Volailles     2017.0  2017.0  Milliers de tonnes
# 654        Viande de Volailles     2017.0  2017.0  Milliers de tonnes
# 655        Viande de Volailles     2017.0  2017.0  Milliers de tonnes
# ...                        ...        ...     ...                 ...
# 180128  Produit Intérieur Brut     2017.0  2017.0      Millions d’USD
# 180129  Produit Intérieur Brut     2007.0  2007.0      Millions d’USD
# 180130  Produit Intérieur Brut     2017.0  2017.0      Millions d’USD
# 180131  Produit Intérieur Brut     2007.0  2007.0      Millions d’USD
# 180132  Produit Intérieur Brut     2017.0  2017.0      Millions d’USD
#
#                value symbole                      symbole_descr
# 651        28.000000       S              Données standardisées
# 652        29.000000       S              Données standardisées
# 653         0.000000       S              Données standardisées
# 654        57.000000       S              Données standardisées
# 655         2.000000       S              Données standardisées
# ...              ...     ...                                ...
# 180128  18391.649820       X  Ciffre de sources internationales
# 180129  14056.884800       X  Ciffre de sources internationales
# 180130  25868.161490       X  Ciffre de sources internationales
# 180131   6958.294807       X  Ciffre de sources internationales
# 180132  22040.654700       X  Ciffre de sources internationales
#
# [5594 rows x 14 columns]

# %%
df_data_select.describe(include = 'all')
# Out:
#        domain_code                      domaine    zone_code   zone  \
# count         2755                         2755  2755.000000   5594
# unique           3                            3          NaN    174
# top            FBS  Nouveaux Bilans Alimentaire          NaN  Tchad
# freq          2061                         2061          NaN     38
# mean           NaN                          NaN   162.972414    NaN
# std            NaN                          NaN   149.453089    NaN
# min            NaN                          NaN     1.000000    NaN
# 25%            NaN                          NaN    70.000000    NaN
# 50%            NaN                          NaN   132.000000    NaN
# 75%            NaN                          NaN   208.000000    NaN
# max            NaN                          NaN   894.000000    NaN
#
#           item_code         item  product_code product    year_code  \
# count   2755.000000         5594   2755.000000    5594  2755.000000
# unique          NaN           19           NaN       4          NaN
# top             NaN  Valeur US $           NaN   Total          NaN
# freq            NaN          347           NaN    2839          NaN
# mean    3659.949546          NaN   5196.377495     NaN  2015.744102
# std     2383.124343          NaN   6383.645159     NaN     3.314467
# min      511.000000          NaN   2734.000000     NaN  2007.000000
# 25%      664.000000          NaN   2734.000000     NaN  2017.000000
# 50%     5142.000000          NaN   2734.000000     NaN  2017.000000
# 75%     5511.000000          NaN   3010.000000     NaN  2017.000000
# max     6110.000000          NaN  22008.000000     NaN  2017.000000
#
#                year               unity         value symbole  \
# count   5594.000000                2755  5.594000e+03    2755
# unique          NaN                   6           NaN       3
# top             NaN  Milliers de tonnes           NaN       S
# freq            NaN                1373           NaN    1373
# mean    2016.381480                 NaN  3.667729e+04     NaN
# std        2.409081                 NaN  4.455700e+05     NaN
# min     2007.000000                 NaN -9.121000e+03     NaN
# 25%     2017.000000                 NaN  9.000000e+00     NaN
# 50%     2017.000000                 NaN  1.366700e+02     NaN
# 75%     2017.000000                 NaN  2.881000e+03     NaN
# max     2017.000000                 NaN  1.947734e+07     NaN
#
#                 symbole_descr
# count                    2755
# unique                      4
# top     Données standardisées
# freq                     1373
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
# Les 2839 NaN correspondent a des colonnes vides de valeurs que nous avons calculé
# A ce stade, pas besoin de les traiter
df_data_select.isna().sum()
# Out:
# domain_code      2839
# domaine          2839
# zone_code        2839
# zone                0
# item_code        2839
# item                0
# product_code     2839
# product             0
# year_code        2839
# year                0
# unity            2839
# value               0
# symbole          2839
# symbole_descr    2839
# dtype: int64

# %%
# Sample de lignes ou il y a un NaN
df_data_select[df_data_select.isna().any(axis=1)].sample(10)
# Out:
#        domain_code domaine  zone_code        zone  item_code  \
# 177771         NaN     NaN        NaN     Irlande        NaN
# 179214         NaN     NaN        NaN     Ukraine        NaN
# 176827         NaN     NaN        NaN     Bahamas        NaN
# 179336         NaN     NaN        NaN    Zimbabwe        NaN
# 176949         NaN     NaN        NaN    Botswana        NaN
# 176950         NaN     NaN        NaN    Botswana        NaN
# 178148         NaN     NaN        NaN        Mali        NaN
# 177250         NaN     NaN        NaN  Costa Rica        NaN
# 179126         NaN     NaN        NaN        Togo        NaN
# 178221         NaN     NaN        NaN  Mauritanie        NaN
#
#                                                      item  product_code  \
# 177771  Disponibilité alimentaire en quantité (kg/pers...           NaN
# 179214                            Importations - Quantité           NaN
# 176827                                         Traitement           NaN
# 179336                                           Semences           NaN
# 176949                                         Production           NaN
# 176950                                            Résidus           NaN
# 178148  Disponibilité de protéines en quantité (g/pers...           NaN
# 177250  Disponibilité de protéines en quantité (g/pers...           NaN
# 179126              Autres utilisations (non alimentaire)           NaN
# 178221                                           Semences           NaN
#
#        product  year_code    year unity    value symbole symbole_descr
# 177771   Total        NaN  2017.0   NaN   980.92     NaN           NaN
# 179214   Total        NaN  2017.0   NaN  2661.00     NaN           NaN
# 176827   Total        NaN  2017.0   NaN    56.00     NaN           NaN
# 179336   Total        NaN  2017.0   NaN    65.00     NaN           NaN
# 176949   Total        NaN  2017.0   NaN   687.00     NaN           NaN
# 176950   Total        NaN  2017.0   NaN    97.00     NaN           NaN
# 178148   Total        NaN  2017.0   NaN    84.74     NaN           NaN
# 177250   Total        NaN  2017.0   NaN    81.15     NaN           NaN
# 179126   Total        NaN  2017.0   NaN    83.00     NaN           NaN
# 178221   Total        NaN  2017.0   NaN    22.00     NaN           NaN

# %%
# On check si ily a des doublons
print('Nombre de doublons dans le df final :', len(df_data_select) - len(df_data_select.drop_duplicates()), 'doublons')
# Out:
# Nombre de doublons dans le df final : 0 doublons

# %% [markdown]
# #### *2.4. Pivot des données*

# %%
# On pivot le df sur Zone et on passe des colonnes en index pour la suite de nos analyses
# On retrouve bien nos 174 pays correspondant au pays ou nous avons des données de dispo alim
# Si nous n'avions pas aligné les deux dataset en amont, nous aurions eu des pays sans données de dispo alim
df_data_pivot = df_data_select.pivot_table(index='zone', values='value', columns=['item', 'product', 'year']).reset_index()
df_data_pivot.head()
# Out:
# item               zone Alimentation pour touristes                      \
# product                                       Total Viande de Volailles
# year                                         2017.0              2017.0
# 0           Afghanistan                         NaN                 NaN
# 1        Afrique du Sud                         0.0                 0.0
# 2               Albanie                         NaN                 NaN
# 3               Algérie                         0.0                 0.0
# 4             Allemagne                         NaN                 NaN
#
# item    Aliments pour animaux                      \
# product                 Total Viande de Volailles
# year                   2017.0              2017.0
# 0                       456.0                 NaN
# 1                      9371.0                 NaN
# 2                       697.0                 NaN
# 3                      4884.0                 NaN
# 4                     30904.0                 NaN
#
# item    Autres utilisations (non alimentaire)                      \
# product                                 Total Viande de Volailles
# year                                   2017.0              2017.0
# 0                                        94.0                 NaN
# 1                                      1448.0                 NaN
# 2                                       177.0                 NaN
# 3                                      2405.0                 NaN
# 4                                      8316.0                 NaN
#
# item    Disponibilité alimentaire (Kcal/personne/jour)                      \
# product                                          Total Viande de Volailles
# year                                            2017.0              2017.0
# 0                                               1997.0                 5.0
# 1                                               2987.0               143.0
# 2                                               3400.0                85.0
# 3                                               3345.0                22.0
# 4                                               3559.0                71.0
#
# item    Disponibilité alimentaire en quantité (kg/personne/an)  ... Résidus  \
# product                                                  Total  ...   Total
# year                                                    2017.0  ...  2017.0
# 0                                                   357.31      ...  -111.0
# 1                                                   556.42      ...  -594.0
# 2                                                  1260.49      ...  -115.0
# 3                                                   798.71      ...   -22.0
# 4                                                   943.24      ...  -831.0
#
# item                        Semences                     Traitement  \
# product Viande de Volailles    Total Viande de Volailles      Total
# year                 2017.0   2017.0              2017.0     2017.0
# 0                       0.0    470.0                 NaN      115.0
# 1                       0.0    212.0                 NaN    21564.0
# 2                       0.0     53.0                 NaN      113.0
# 3                       0.0    358.0                 NaN      993.0
# 4                     -38.0   1712.0                 NaN    51109.0
#
# item                                   Valeur US $                \
# product Viande de Volailles Produit Intérieur Brut
# year                 2017.0                 2007.0        2017.0
# 0                       NaN           9.412162e+03  1.889635e+04
# 1                       NaN           3.330771e+05  3.808514e+05
# 2                       NaN           1.067732e+04  1.301973e+04
# 3                       NaN           1.349771e+05  1.700970e+05
# 4                     167.0           3.421054e+06  3.690849e+06
#
# item    Variation de stock
# product              Total Viande de Volailles
# year                2017.0              2017.0
# 0                    426.0                 0.0
# 1                   -322.0                 0.0
# 2                     72.0                 4.0
# 3                    374.0                 0.0
# 4                    651.0               -29.0
#
# [5 rows x 39 columns]

# %% [markdown]
# ##### *2.4. Sélection des features*

# %%
# On regarde ou on a un max de données à exploiter, plus la valeur est proche de 0 plus on a de données
df_data_pivot.isna().sum()
# Out:
# item                                                           product                 year
# zone                                                                                               0
# Alimentation pour touristes                                    Total                   2017.0     95
#                                                                Viande de Volailles     2017.0     96
# Aliments pour animaux                                          Total                   2017.0      0
#                                                                Viande de Volailles     2017.0    173
# Autres utilisations (non alimentaire)                          Total                   2017.0      0
#                                                                Viande de Volailles     2017.0    140
# Disponibilité alimentaire (Kcal/personne/jour)                 Total                   2017.0      2
#                                                                Viande de Volailles     2017.0      2
# Disponibilité alimentaire en quantité (kg/personne/an)         Total                   2017.0      2
#                                                                Viande de Volailles     2017.0      2
# Disponibilité de matière grasse en quantité (g/personne/jour)  Total                   2017.0      2
#                                                                Viande de Volailles     2017.0      2
# Disponibilité de protéines en quantité (g/personne/jour)       Total                   2017.0      2
#                                                                Viande de Volailles     2017.0      2
# Disponibilité intérieure                                       Total                   2017.0      0
#                                                                Viande de Volailles     2017.0      4
# Exportations - Quantité                                        Total                   2017.0      0
#                                                                Viande de Volailles     2017.0     39
# Importations - Quantité                                        Total                   2017.0      0
#                                                                Viande de Volailles     2017.0      4
# Nourriture                                                     Total                   2017.0      0
#                                                                Viande de Volailles     2017.0      4
# Pertes                                                         Total                   2017.0      4
#                                                                Viande de Volailles     2017.0    107
# Population totale                                              Population-Estimations  2007.0      1
#                                                                                        2017.0      0
# Production                                                     Total                   2017.0      0
#                                                                Viande de Volailles     2017.0      6
# Résidus                                                        Total                   2017.0      4
#                                                                Viande de Volailles     2017.0     10
# Semences                                                       Total                   2017.0      4
#                                                                Viande de Volailles     2017.0    173
# Traitement                                                     Total                   2017.0      4
#                                                                Viande de Volailles     2017.0    128
# Valeur US $                                                    Produit Intérieur Brut  2007.0      1
#                                                                                        2017.0      0
# Variation de stock                                             Total                   2017.0      0
#                                                                Viande de Volailles     2017.0      5
# dtype: int64

# %%
# Liste des données utiles (features)

# Infos pays
    # pays
    # population
    # % evolution population

# Infos dispo kcla et prot, l'idée est de voir la dispo du poulet pour les habitants
    # dispo totale kcal et protéines
    # ratio dispo chicken / total kcal et protéines (on regarde ce que représente le poulet dans la dispo alimentaire totale pour  voir si les habitant en on beaucoup à dispo)


# La l'idée est de voir comment le poulet arrive dans le pays (import/export, production)
    # import/export du poulet (pour voir si ça importe beaucoup du poulet, on fait le ratio de l'import rapport à l'export du poulet et non rapport au total)

    # Voir si ça produit du poulet en masse ou pas ? (ratio de production poulet rapport à la production totale ?)
    
# Prendre le  TAS et le TDI
# Faire attention au NaN lors des calculs
    # TAS = Prod / (prod + import - export)
    # TDI = Import / (prod + import - export)

# %%
# On créé un nouveau dataframe avec les données qui nous intéressent
# Trame de sélection ['item']['product']['year']
# Définition de deux variables pour la sélection des années (on pourrait faire un min et max aussi)

year_a, year_b = 2007, 2017

# On créé un df vierge
df_final = pd.DataFrame()

# Données de pays et population
df_final['pays'] = df_data_pivot['zone'] # Servira d'index par la suite car les données sont propres à un pays (clé primaire)

df_final['pop_2017'] = df_data_pivot['Population totale']['Population-Estimations'][year_b]
# df_final['evo_pop_(%)'] = df_data_pivot['Population totale']['Population-Estimations'][year_b]/df_data_pivot['Population totale']['Population-Estimations'][year_a]
df_final['pib_2017'] = df_data_pivot['Valeur US $']['Produit Intérieur Brut'][year_b]


# Données dispo en kcal
# df_final['ratio_chicken_kcal_(%)'] = df_data_pivot['Disponibilité alimentaire (Kcal/personne/jour)']['Viande de Volailles'][year_b]/df_data_pivot['Disponibilité alimentaire (Kcal/personne/jour)']['Total'][year_b]
df_final['dispo_chicken_(kcal)'] = df_data_pivot['Disponibilité alimentaire (Kcal/personne/jour)']['Viande de Volailles'][year_b]
# df_final['dispo_total_(kcal)'] = df_data_pivot['Disponibilité alimentaire (Kcal/personne/jour)']['Total'][year_b]

# Dispo protéines ?
# df_final['ratio_chicken_prot_(%)'] = df_data_pivot['Disponibilité de protéines en quantité (g/personne/jour)']['Viande de Volailles'][year_b]/df_data_pivot['Disponibilité de protéines en quantité (g/personne/jour)']['Total'][year_b]
# df_final['dispo_chicken_prot_(g)'] = df_data_pivot['Disponibilité de protéines en quantité (g/personne/jour)']['Viande de Volailles'][year_b]
# df_final['dispo_total_prot_(g)'] = df_data_pivot['Disponibilité de protéines en quantité (g/personne/jour)']['Total'][year_b]

# Import et export en milliers de tonnes (faire juste une colonne avec % ?)
# df_final['ratio_imp_exp_chicken_(%)'] = df_data_pivot['Importations - Quantité']['Viande de Volailles'][year_b]/df_data_pivot['Exportations - Quantité']['Viande de Volailles'][year_b]
df_final['import_chicken_(milliers)'] = df_data_pivot['Importations - Quantité']['Viande de Volailles'][year_b]
# df_final['export_chicken_(milliers)'] = df_data_pivot['Exportations - Quantité']['Viande de Volailles'][year_b]

# Données diverses sur le poulet (à compléter par la suite)
df_final['production_chicken_(milliers)'] = df_data_pivot['Production']['Viande de Volailles'][year_b]
# df_final['dispo_chicken_(milliers)'] = df_data_pivot['Disponibilité intérieure']['Viande de Volailles'][year_b]



# On rajoute des ratio TAS et TDI

# On regarde notre df final
# Comme on a créé un nouveau df pas besoin de rest l'index
df_final.sample(5)
# Out:
#                    pays   pop_2017      pib_2017  dispo_chicken_(kcal)  \
# 51                Fidji    877.459  5.353492e+03                  97.0
# 90    Macédoine du Nord   2081.996  1.130706e+04                  68.0
# 31               Canada  36732.095  1.649519e+06                 154.0
# 137        Sainte-Lucie    180.954  1.996770e+03                 241.0
# 6    Antigua-et-Barbuda     95.426  1.467978e+03                 233.0
#
#      import_chicken_(milliers)  production_chicken_(milliers)
# 51                         3.0                           23.0
# 90                        40.0                            2.0
# 31                       182.0                         1417.0
# 137                       10.0                            1.0
# 6                          7.0                            0.0

# %%
# Passer les pays en index (plus simple pour la suite, on aura que des données numériques)
df_final.set_index('pays', inplace = True)

# %%
df_final
# Out:
#                          pop_2017      pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan             36296.113  1.889635e+04                   5.0
# Afrique du Sud          57009.756  3.808514e+05                 143.0
# Albanie                  2884.169  1.301973e+04                  85.0
# Algérie                 41389.189  1.700970e+05                  22.0
# Allemagne               82658.409  3.690849e+06                  71.0
# ...                           ...           ...                   ...
# Émirats arabes unis      9487.203  3.856055e+05                 147.0
# Équateur                16785.361  1.042959e+05                  83.0
# États-Unis d'Amérique  325084.756  1.947734e+07                 219.0
# Éthiopie               106399.924  7.679469e+04                   0.0
# Îles Salomon              636.039  1.469790e+03                  18.0
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                                 29.0
# Afrique du Sud                             514.0
# Albanie                                     38.0
# Algérie                                      2.0
# Allemagne                                  842.0
# ...                                          ...
# Émirats arabes unis                        433.0
# Équateur                                     0.0
# États-Unis d'Amérique                      123.0
# Éthiopie                                     1.0
# Îles Salomon                                 6.0
#
#                        production_chicken_(milliers)
# pays
# Afghanistan                                     28.0
# Afrique du Sud                                1667.0
# Albanie                                         13.0
# Algérie                                        275.0
# Allemagne                                     1514.0
# ...                                              ...
# Émirats arabes unis                             48.0
# Équateur                                       340.0
# États-Unis d'Amérique                        21914.0
# Éthiopie                                        14.0
# Îles Salomon                                     0.0
#
# [174 rows x 5 columns]

# %% [markdown]
# ### 4. Nettoyage du df final

# %% [markdown]
# ##### *2.4. Gestion des NaN*

# %%
# Gestion des NaN et autres
# On remarque des valeurs NaN et inf dans ratio_imp_exp (pas bon signe)
df_final.describe()
# Out:
#            pop_2017      pib_2017  dispo_chicken_(kcal)  \
# count  1.740000e+02  1.740000e+02            172.000000
# mean   4.235212e+04  5.320674e+05             74.558140
# std    1.522445e+05  2.054922e+06             60.571277
# min    5.204500e+01  1.881820e+02              0.000000
# 25%    2.513328e+03  1.167764e+04             22.000000
# 50%    9.608513e+03  4.317130e+04             64.000000
# 75%    2.971320e+04  2.418941e+05            105.500000
# max    1.421022e+06  1.947734e+07            243.000000
#
#        import_chicken_(milliers)  production_chicken_(milliers)
# count                 170.000000                     168.000000
# mean                   89.529412                     725.190476
# std                   186.669983                    2501.457125
# min                     0.000000                       0.000000
# 25%                     3.000000                      13.750000
# 50%                    16.000000                      70.000000
# 75%                    81.250000                     409.750000
# max                  1069.000000                   21914.000000

# %%
# Infos de bases sur le df
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174 entries, Afghanistan to Îles Salomon
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   pop_2017                       174 non-null    float64
#  1   pib_2017                       174 non-null    float64
#  2   dispo_chicken_(kcal)           172 non-null    float64
#  3   import_chicken_(milliers)      170 non-null    float64
#  4   production_chicken_(milliers)  168 non-null    float64
# dtypes: float64(5)
# memory usage: 8.2+ KB

# %%
# On regarde le nombre de manquants par colonne
print('Nombre de lignes :', len(df_final))
df_final.isna().sum()
# Out:
# Nombre de lignes : 174
# pop_2017                         0
# pib_2017                         0
# dispo_chicken_(kcal)             2
# import_chicken_(milliers)        4
# production_chicken_(milliers)    6
# dtype: int64

# %%
# Regarde les lignes ou il ya au moins un NaN
print('Nombre de lignes :', len(df_final))
print('Nombre de lignes avec au moins UN NaN :', len(df_final[df_final.isna().any(axis=1)]))
df_final[df_final.isna().any(axis=1)].head(10)
# Out:
# Nombre de lignes : 174
# Nombre de lignes avec au moins UN NaN : 6
#                                         pop_2017      pib_2017  \
# pays
# Bermudes                                  63.049   7142.316000
# Brunéi Darussalam                        424.473  12128.166610
# Djibouti                                 944.099   2766.868072
# Maldives                                 496.402   4754.185598
# Ouzbékistan                            31959.785  62081.322740
# République démocratique populaire lao   6953.035  17071.155480
#
#                                        dispo_chicken_(kcal)  \
# pays
# Bermudes                                                NaN
# Brunéi Darussalam                                       NaN
# Djibouti                                                9.0
# Maldives                                               47.0
# Ouzbékistan                                             6.0
# République démocratique populaire lao                  41.0
#
#                                        import_chicken_(milliers)  \
# pays
# Bermudes                                                     NaN
# Brunéi Darussalam                                            NaN
# Djibouti                                                     3.0
# Maldives                                                    12.0
# Ouzbékistan                                                  NaN
# République démocratique populaire lao                        NaN
#
#                                        production_chicken_(milliers)
# pays
# Bermudes                                                         NaN
# Brunéi Darussalam                                                NaN
# Djibouti                                                         NaN
# Maldives                                                         NaN
# Ouzbékistan                                                      NaN
# République démocratique populaire lao                            NaN

# %% [markdown]
# # ***--- A voir ---***

# %%
# # Test 01
# # Dans un premier temps on supprime les lignes ou l'on a que des NaN (donc les pays qui n'ont que la donnée population)
# # En gros ce sont des pays ou nous n'avons aucune données exploitables
# df_final.dropna(axis = 0, thresh = 4, inplace = True) # On supprime les lignes ou il y a au moins 4 NaN
# df_final

# %%
# Test 02
# Dans un premier temps on supprime les lignes ou l'on un NaN
df_final.dropna(axis = 0, inplace = True) # On supprime les lignes ou il y a au moins 1 NaN
df_final
# Out:
#                          pop_2017      pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan             36296.113  1.889635e+04                   5.0
# Afrique du Sud          57009.756  3.808514e+05                 143.0
# Albanie                  2884.169  1.301973e+04                  85.0
# Algérie                 41389.189  1.700970e+05                  22.0
# Allemagne               82658.409  3.690849e+06                  71.0
# ...                           ...           ...                   ...
# Émirats arabes unis      9487.203  3.856055e+05                 147.0
# Équateur                16785.361  1.042959e+05                  83.0
# États-Unis d'Amérique  325084.756  1.947734e+07                 219.0
# Éthiopie               106399.924  7.679469e+04                   0.0
# Îles Salomon              636.039  1.469790e+03                  18.0
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                                 29.0
# Afrique du Sud                             514.0
# Albanie                                     38.0
# Algérie                                      2.0
# Allemagne                                  842.0
# ...                                          ...
# Émirats arabes unis                        433.0
# Équateur                                     0.0
# États-Unis d'Amérique                      123.0
# Éthiopie                                     1.0
# Îles Salomon                                 6.0
#
#                        production_chicken_(milliers)
# pays
# Afghanistan                                     28.0
# Afrique du Sud                                1667.0
# Albanie                                         13.0
# Algérie                                        275.0
# Allemagne                                     1514.0
# ...                                              ...
# Émirats arabes unis                             48.0
# Équateur                                       340.0
# États-Unis d'Amérique                        21914.0
# Éthiopie                                        14.0
# Îles Salomon                                     0.0
#
# [168 rows x 5 columns]

# %%
print('Nombre de lignes :', len(df_final))
print('Nombre de lignes avec au moins UN NaN :', len(df_final[df_final.isna().any(axis=1)]))

df_final[df_final.isna().any(axis=1)].head(10)
# Out:
# Nombre de lignes : 168
# Nombre de lignes avec au moins UN NaN : 0
# Empty DataFrame
# Columns: [pop_2017, pib_2017, dispo_chicken_(kcal), import_chicken_(milliers), production_chicken_(milliers)]
# Index: []

# %% [markdown]
# # ***--- Fin à voir ---***

# %% [markdown]
# ##### *2.4. Gestion des inf (Si besoin)*

# %%
# On regarde également les valeur inf, une seule colonne en contient, ce qui  est plus simple à visualiser
# Ce sont des pays qui ont fait de l'importation mais pas d'exportation
# print('Nombre de lignes avec inf dans ratio_imp_exp :', len(df_final.loc[df_final['ratio_imp_exp_chicken_(%)'] == np.inf]))
# df_final.loc[df_final['ratio_imp_exp_chicken_(%)'] == np.inf].sample(5)

# %%
# On compte les NaN et inf dans ratio_imp_exp
# df_final[['ratio_imp_exp_chicken_(%)']].value_counts(dropna = False, ascending = False)

# %%
# On regarde les pays qui n'ont pas fait d'export de poulet, ce qui explique nos valeur inf pour le ratio
# df_t = df_dispo_alim.loc[(df_dispo_alim['item'] == 'Exportations - Quantité') & (df_dispo_alim['product'] == 'Viande de Volailles')]
# print(len(df_t.loc[df_t['value'] == 0]))
# df_t.loc[df_t['value'] == 0].sample(5)

# %%
# Conclusions après analyse de ces valeurs abérrantes :

# Certains pays n'ont pas d'évolution car pas de données de 2000
# Si ils ont toutes les autres données, on pourrait les garder et remplacer l'evo_pop par 0

# Les pays n'ayant pas de données quand aux ratios calculés ne nous serviront pas pour l'analyse
# On supprimera donc ces lignes qui contiennent des NaN dans les ratios et autres données de dispo alim

# Il est intéressant de regarde les pays ayant un ratio import/export = inf (describe du df fait précedemment)
# On remarque que ces pays ont importé du poulet mais n'en ont pas exporté, ce qui explique ce ratio
# On ne peux donc pas supprimer ces pays car ils ont tout les autres ratios nécessaires pour l'étude
# Dans la logique, il faut remplacer ce ratio car ils n'ont fait que de l'import de poulet, mais par quoi ?

# %%
# On test ce que ça fait de supprimer simplement toutes ces valeurs abérrantes
# On remarque qu'il ne nous resterais que 82 pays sur un dataset de base de 174 pays... Soit moins de la moitié...
# df_final.replace([np.inf, -np.inf], np.nan).dropna().reset_index().drop(['index'], axis=1)

# %% [markdown]
# ### 4. Vérification finale avant analyse

# %%
df_final.head()
# Out:
#                  pop_2017      pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan     36296.113  1.889635e+04                   5.0
# Afrique du Sud  57009.756  3.808514e+05                 143.0
# Albanie          2884.169  1.301973e+04                  85.0
# Algérie         41389.189  1.700970e+05                  22.0
# Allemagne       82658.409  3.690849e+06                  71.0
#
#                 import_chicken_(milliers)  production_chicken_(milliers)
# pays
# Afghanistan                          29.0                           28.0
# Afrique du Sud                      514.0                         1667.0
# Albanie                              38.0                           13.0
# Algérie                               2.0                          275.0
# Allemagne                           842.0                         1514.0

# %%
# On vérifie que l'on n'a plus de valeurs qui poseront problèmes
df_final.isna().sum()
# Out:
# pop_2017                         0
# pib_2017                         0
# dispo_chicken_(kcal)             0
# import_chicken_(milliers)        0
# production_chicken_(milliers)    0
# dtype: int64

# %%
df_final.describe()
# Out:
#            pop_2017      pib_2017  dispo_chicken_(kcal)  \
# count  1.680000e+02  1.680000e+02            168.000000
# mean   4.362160e+04  5.504392e+05             75.720238
# std    1.547882e+05  2.089152e+06             60.747236
# min    5.204500e+01  1.881820e+02              0.000000
# 25%    2.911678e+03  1.261564e+04             22.000000
# 50%    9.815582e+03  4.817392e+04             65.500000
# 75%    3.013874e+04  2.609947e+05            107.500000
# max    1.421022e+06  1.947734e+07            243.000000
#
#        import_chicken_(milliers)  production_chicken_(milliers)
# count                 168.000000                     168.000000
# mean                   90.505952                     725.190476
# std                   187.566547                    2501.457125
# min                     0.000000                       0.000000
# 25%                     3.000000                      13.750000
# 50%                    16.000000                      70.000000
# 75%                    82.500000                     409.750000
# max                  1069.000000                   21914.000000

# %% [markdown]
# ##### *2.4. Dépendance et infos sur les variables*

# %%
# On regarde la dépendance entre nos variables car si elles sont trop corrélées cela risque de poser des soucis lors de l'analyse

# %%
# Dépendance linéaire entre les variables :

# If the degree of correlation is high enough between variables, it can cause problems when fitting and interpreting the regression model

# The value for VIF starts at 1 and has no upper limit. A general rule of thumb for interpreting VIFs is as follows :

# A value of 1 indicates there is no correlation between a given explanatory variable and any other explanatory variables in the model
# A value between 1 and 5 indicates moderate correlation between a given explanatory variable and other explanatory variables in the model, but this is often not severe enough to require attention
# A value greater than 5 indicates potentially severe correlation between a given explanatory variable and other explanatory variables in the model

# %%
# Explication du VIF :

# Multicollinearity in regression analysis occurs when two or more explanatory variables are highly correlated with each other, such that they do not provide unique or independent information
# in the regression model.

# If the degree of correlation is high enough between variables, it can cause problems when fitting and interpreting the regression model. 

# One way to detect multicollinearity is by using a metric known as the variance inflation factor (VIF), which measures the correlation and strength of correlation between
# the explanatory variables in a regression model.

# %%
# Calcul de la corrélation entre nos variables choisies (Variance Inflation Factor)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# VIF dataframe
vif_data = pd.DataFrame() # On créé un df vide
vif_data["feature"] = df_final.columns # On prend les colonnes de notre df
  
# Calcul du VIF pour chaque feature
vif_data["VIF"] = [variance_inflation_factor(df_final.values, i) for i in range(len(df_final.columns))]

# df de sortie avec les valeurs VIF
vif_data
# Out:
#                          feature       VIF
# 0                       pop_2017  1.761122
# 1                       pib_2017  3.054129
# 2           dispo_chicken_(kcal)  1.344818
# 3      import_chicken_(milliers)  1.351182
# 4  production_chicken_(milliers)  3.758894

# %%
# Matrice de corrélation
# Calculate pairwise-correlation : df scaler
matrix = df_final.corr()

# Triangle de corrélations
mask = np.triu(np.ones_like(matrix, dtype=bool))
plt.figure(figsize=(8, 4))
sns.heatmap(matrix, mask=mask, annot=True, cmap='OrRd')
plt.show()

# %% [markdown]
# ##### *2.4. Recherche d'outliers*

# %%
# On fait un boxplot sur les différentes colonnes de notre df
df_final.columns.tolist()
# Out:
# ['pop_2017',
#  'pib_2017',
#  'dispo_chicken_(kcal)',
#  'import_chicken_(milliers)',
#  'production_chicken_(milliers)']

# %%
# Au vu du boxplot, il serait peut être plus intéressant de chercher des outliers sur un df standardisé
# Pas pertinent car les unitées sont différentes, on pourrait faire cela feature par feature mais est ce pertinent ?
plt.figure(figsize = (21,6))
sns.boxplot(data = df_final, orient = 'h', color = 'DarkRed')
# Out:
# <AxesSubplot:>

# %%
df_final.describe()
# Out:
#            pop_2017      pib_2017  dispo_chicken_(kcal)  \
# count  1.680000e+02  1.680000e+02            168.000000
# mean   4.362160e+04  5.504392e+05             75.720238
# std    1.547882e+05  2.089152e+06             60.747236
# min    5.204500e+01  1.881820e+02              0.000000
# 25%    2.911678e+03  1.261564e+04             22.000000
# 50%    9.815582e+03  4.817392e+04             65.500000
# 75%    3.013874e+04  2.609947e+05            107.500000
# max    1.421022e+06  1.947734e+07            243.000000
#
#        import_chicken_(milliers)  production_chicken_(milliers)
# count                 168.000000                     168.000000
# mean                   90.505952                     725.190476
# std                   187.566547                    2501.457125
# min                     0.000000                       0.000000
# 25%                     3.000000                      13.750000
# 50%                    16.000000                      70.000000
# 75%                    82.500000                     409.750000
# max                  1069.000000                   21914.000000

# %%
# Recherche d'outlieravec les IQR
# On ordonne la serie triée
outlier = sorted(df_final['pib_2017'])

# On calcule l'interquartile
q1, q3= np.percentile(outlier, [25, 75])
iqr = q3 - q1
print("Q1 => " + str(q1))
print("Q3 => " + str(q3))
print("IQR => " + str(iqr))

# On calcule les valeurs limite
lower_bound = q1 -(1.5 * iqr)
upper_bound = q3 +(1.5 * iqr)
print("Lower_bound => " + str(lower_bound))
print("Upper_bound => " + str(upper_bound))

# On cherche les outliers
result = df_final[(df_final['pib_2017'] > upper_bound) | (df_final['pib_2017'] < lower_bound)]

# On observe
print("")
print("Nombre d'outliers détectés => " + str(len(result)))
result['pib_2017']
# Out:
# Q1 => 12615.6418875
# Q3 => 260994.6546
# IQR => 248379.0127125
# Lower_bound => -359952.87718124996
# Upper_bound => 633563.17366875
#
# Nombre d'outliers détectés => 22
# pays
# Allemagne                                              3.690849e+06
# Arabie saoudite                                        6.885861e+05
# Argentine                                              6.436284e+05
# Australie                                              1.412243e+06
# Brésil                                                 2.063515e+06
# Canada                                                 1.649519e+06
# Chine, Taiwan Province de                              1.270220e+07
# Chine, continentale                                    1.231049e+07
# Espagne                                                1.313245e+06
# France                                                 2.595151e+06
# Fédération de Russie                                   1.574199e+06
# Inde                                                   2.624329e+06
# Indonésie                                              1.015619e+06
# Italie                                                 1.961796e+06
# Japon                                                  4.930837e+06
# Mexique                                                1.158912e+06
# Pays-Bas                                               8.338696e+05
# Royaume-Uni de Grande-Bretagne et d'Irlande du Nord    2.683399e+06
# République de Corée                                    1.623901e+06
# Suisse                                                 7.044785e+05
# Turquie                                                8.589886e+05
# États-Unis d'Amérique                                  1.947734e+07
# Name: pib_2017, dtype: float64

# %% [markdown]
# ---
# # ***--- A voir ---***

# %% [markdown]
# # Df de test pour tester des trucs en avance

# %%
df_final.head()
# Out:
#                  pop_2017      pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan     36296.113  1.889635e+04                   5.0
# Afrique du Sud  57009.756  3.808514e+05                 143.0
# Albanie          2884.169  1.301973e+04                  85.0
# Algérie         41389.189  1.700970e+05                  22.0
# Allemagne       82658.409  3.690849e+06                  71.0
#
#                 import_chicken_(milliers)  production_chicken_(milliers)
# pays
# Afghanistan                          29.0                           28.0
# Afrique du Sud                      514.0                         1667.0
# Albanie                              38.0                           13.0
# Algérie                               2.0                          275.0
# Allemagne                           842.0                         1514.0

# %%
# Applique un background au df pour avoir un visu des valeurs
# test.style.background_gradient(cmap='OrRd')

# %% [markdown]
# ### 4. Standardisation des données

# %%
# Pour tester, on fait un fillna avant le scaling (ne pose pas de pbs au scaling mais pour d'autres analyses, ACP, kmeans, ...)
# test = test.fillna(0)
df_final.isna().sum()
# Out:
# pop_2017                         0
# pib_2017                         0
# dispo_chicken_(kcal)             0
# import_chicken_(milliers)        0
# production_chicken_(milliers)    0
# dtype: int64

# %%
# StandardScaler
# Scaling (StandardScaler()), transformation des données avec une moyenne = 0 et un ecart-type = 1

# On instancie notre scaler : 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# On entraine et transforme nos données :
X_scaled = scaler.fit_transform(df_final)

# On remet notre scale sous forme de df
df_scaled = pd.DataFrame(X_scaled, columns = df_final.columns, index =  df_final.index)
df_scaled
# Out:
#                        pop_2017  pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan           -0.047467 -0.255191             -1.167652
# Afrique du Sud         0.086752 -0.081418              1.110847
# Albanie               -0.263969 -0.258012              0.153217
# Algérie               -0.014465 -0.182600             -0.886968
# Allemagne              0.252949  1.507692             -0.077935
# ...                         ...       ...                   ...
# Émirats arabes unis   -0.221183 -0.079136              1.176891
# Équateur              -0.173892 -0.214191              0.120195
# États-Unis d'Amérique  1.823812  9.086692              2.365673
# Éthiopie               0.406788 -0.227394             -1.250207
# Îles Salomon          -0.278536 -0.263557             -0.953011
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                            -0.328896
# Afrique du Sud                          2.264583
# Albanie                                -0.280769
# Algérie                                -0.473275
# Allemagne                               4.018524
# ...                                          ...
# Émirats arabes unis                     1.831446
# Équateur                               -0.483970
# États-Unis d'Amérique                   0.173758
# Éthiopie                               -0.478622
# Îles Salomon                           -0.451885
#
#                        production_chicken_(milliers)
# pays
# Afghanistan                                -0.279547
# Afrique du Sud                              0.377630
# Albanie                                    -0.285561
# Algérie                                    -0.180509
# Allemagne                                   0.316283
# ...                                              ...
# Émirats arabes unis                        -0.271528
# Équateur                                   -0.154447
# États-Unis d'Amérique                       8.495910
# Éthiopie                                   -0.285160
# Îles Salomon                               -0.290774
#
# [168 rows x 5 columns]

# %%
# RobustScaler
# Scaling (RobustScaler()), transformation des données

# On instancie notre scaler : 
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()

# On entraine et transforme nos données :
X_scaled_robust = scaler.fit_transform(df_final)

# On remet notre scale sous forme de df
df_scaled_robust = pd.DataFrame(X_scaled_robust, columns = df_final.columns, index =  df_final.index)
df_scaled_robust
# Out:
#                         pop_2017   pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan             0.972581  -0.117875             -0.707602
# Afrique du Sud          1.733356   1.339395              0.906433
# Albanie                -0.254578  -0.141534              0.228070
# Algérie                 1.159641   0.490875             -0.508772
# Allemagne               2.675384  14.665793              0.064327
# ...                          ...        ...                   ...
# Émirats arabes unis    -0.012061   1.358535              0.953216
# Équateur                0.255987   0.225953              0.204678
# États-Unis d'Amérique  11.579260  78.223852              1.795322
# Éthiopie                3.547366   0.115230             -0.766082
# Îles Salomon           -0.337148  -0.188036             -0.555556
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                             0.163522
# Afrique du Sud                          6.264151
# Albanie                                 0.276730
# Algérie                                -0.176101
# Allemagne                              10.389937
# ...                                          ...
# Émirats arabes unis                     5.245283
# Équateur                               -0.201258
# États-Unis d'Amérique                   1.345912
# Éthiopie                               -0.188679
# Îles Salomon                           -0.125786
#
#                        production_chicken_(milliers)
# pays
# Afghanistan                                -0.106061
# Afrique du Sud                              4.032828
# Albanie                                    -0.143939
# Algérie                                     0.517677
# Allemagne                                   3.646465
# ...                                              ...
# Émirats arabes unis                        -0.055556
# Équateur                                    0.681818
# États-Unis d'Amérique                      55.161616
# Éthiopie                                   -0.141414
# Îles Salomon                               -0.176768
#
# [168 rows x 5 columns]

# %%
# Quelques graphes

# %%
# Calcul pairwise-correlation : standardscaler
matrix = df_scaled.corr()

# Triangle de corrélations
mask = np.triu(np.ones_like(matrix, dtype=bool))
plt.figure(figsize=(4, 2))
sns.heatmap(matrix, mask=mask, annot=True, cmap='OrRd')
plt.show()

# %%
# Calcul pairwise-correlation : robustscaler
matrix = df_scaled_robust.corr()

# Triangle de corrélations
mask = np.triu(np.ones_like(matrix, dtype=bool))
plt.figure(figsize=(4, 2))
sns.heatmap(matrix, mask=mask, annot=True, cmap='OrRd')
plt.show()

# %%
# Boxplot sur données standardisées pour vis de la répartition
plt.figure(figsize = (21,6))

sns.boxplot(data = df_scaled, orient = 'h', showmeans = True, palette = 'OrRd', notch=True)
plt.title('Boxplot par feature (std scale)', fontdict = {'fontsize' : '14', 'color' : 'black', 'fontweight' : 'bold'})
plt.ylabel('Features', fontdict = {'fontsize' : '12', 'color' : 'black', 'fontweight' : 'bold'})

plt.show()

# %%
# Visu des valeurs extrêmes sur production_chicken
df_scaled.loc[df_scaled['production_chicken_(milliers)'] > 4]
# Out:
#                        pop_2017  pib_2017  dispo_chicken_(kcal)  \
# pays
# Brésil                 1.064055  0.726419              2.118010
# Chine, continentale    8.925217  5.645932             -0.276066
# États-Unis d'Amérique  1.823812  9.086692              2.365673
#
#                        import_chicken_(milliers)  \
# pays
# Brésil                                 -0.467928
# Chine, continentale                     1.933046
# États-Unis d'Amérique                   0.173758
#
#                        production_chicken_(milliers)
# pays
# Brésil                                      5.403289
# Chine, continentale                         7.021171
# États-Unis d'Amérique                       8.495910

# %%
# Boxplot sur données standardisées robust pour vis de la répartition
plt.figure(figsize = (21,6))

sns.boxplot(data = df_scaled_robust, orient = 'h', showmeans = True, palette = 'OrRd', notch=True)
plt.title('Boxplot par feature (robust scale)', fontdict = {'fontsize' : '14', 'color' : 'black', 'fontweight' : 'bold'})
plt.ylabel('Features', fontdict = {'fontsize' : '12', 'color' : 'black', 'fontweight' : 'bold'})

plt.show()

# %%
# Visu des dispersion selon la méthode de scalling
for i in df_scaled.columns:
    fig, ax = plt.subplots(1, 1, figsize = (21, 1))
    sns.kdeplot(ax = ax, data = df_scaled, x = i, fill = True, color = 'Red')
    sns.kdeplot(ax = ax, data = df_scaled_robust, x = i, fill = True, color = 'Blue')
    plt.show()

# %% [markdown]
# # ***--- Fin à voir ---***
# ---

# %% [markdown]
# ---
# ## Partie 3 - Exploration

# %%
# Faire un sch
# Faire un kmean
# Faire une acp

# %% [markdown]
# ### 3. CAH (sur df_scaled)
# ---

# %%
# On importe les lib nécessaires
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.cluster import AgglomerativeClustering

# %%
df_scaled
# Out:
#                        pop_2017  pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan           -0.047467 -0.255191             -1.167652
# Afrique du Sud         0.086752 -0.081418              1.110847
# Albanie               -0.263969 -0.258012              0.153217
# Algérie               -0.014465 -0.182600             -0.886968
# Allemagne              0.252949  1.507692             -0.077935
# ...                         ...       ...                   ...
# Émirats arabes unis   -0.221183 -0.079136              1.176891
# Équateur              -0.173892 -0.214191              0.120195
# États-Unis d'Amérique  1.823812  9.086692              2.365673
# Éthiopie               0.406788 -0.227394             -1.250207
# Îles Salomon          -0.278536 -0.263557             -0.953011
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                            -0.328896
# Afrique du Sud                          2.264583
# Albanie                                -0.280769
# Algérie                                -0.473275
# Allemagne                               4.018524
# ...                                          ...
# Émirats arabes unis                     1.831446
# Équateur                               -0.483970
# États-Unis d'Amérique                   0.173758
# Éthiopie                               -0.478622
# Îles Salomon                           -0.451885
#
#                        production_chicken_(milliers)
# pays
# Afghanistan                                -0.279547
# Afrique du Sud                              0.377630
# Albanie                                    -0.285561
# Algérie                                    -0.180509
# Allemagne                                   0.316283
# ...                                              ...
# Émirats arabes unis                        -0.271528
# Équateur                                   -0.154447
# États-Unis d'Amérique                       8.495910
# Éthiopie                                   -0.285160
# Îles Salomon                               -0.290774
#
# [168 rows x 5 columns]

# %%
# On applique sur le df standardisé
Z = linkage(df_scaled, method = "ward", optimal_ordering = True)
pd.DataFrame(Z).sort_values(by = 3, ascending = True, inplace  = True)

# %%
# On trace le dendrogramme
fig, ax = plt.subplots(1, 1, figsize = (16, 8))

dendrogram(Z, ax = ax)

plt.axhline(y=11, color='black', linestyle='dashed')
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.ylabel("Distance.")
plt.show()

# %%
# On remarque un groupe de trois qui se démarque, outliers ?

# %%
# On défini les paramètres du clustering après avoir regarder le dendrogramme
cah = AgglomerativeClustering(n_clusters = 5, linkage = 'ward')

# %%
# On entraine sur les données
cah.fit(df_scaled)
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
# Visu des clustering effectués sur le df scaled
cah_cluster = pd.DataFrame(cah.labels_).rename(columns = {0 : 'cah_cluster'})
cah_cluster
# Out:
#      cah_cluster
# 0              0
# 1              0
# 2              0
# 3              0
# 4              2
# ..           ...
# 163            0
# 164            0
# 165            4
# 166            0
# 167            0
#
# [168 rows x 1 columns]

# %%
# On regarde le nombre d'individus par cluster
# Ce clustering est bizarre...
cah_cluster['cah_cluster'].value_counts()
# Out:
# 0    137
# 1     22
# 2      6
# 3      2
# 4      1
# Name: cah_cluster, dtype: int64

# %%
# On ajoute les cluster kmeans au df
df_scaled_cah = df_scaled.copy()
df_scaled_cah['kmeans_cluster'] = cah.labels_
df_scaled_cah
# Out:
#                        pop_2017  pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan           -0.047467 -0.255191             -1.167652
# Afrique du Sud         0.086752 -0.081418              1.110847
# Albanie               -0.263969 -0.258012              0.153217
# Algérie               -0.014465 -0.182600             -0.886968
# Allemagne              0.252949  1.507692             -0.077935
# ...                         ...       ...                   ...
# Émirats arabes unis   -0.221183 -0.079136              1.176891
# Équateur              -0.173892 -0.214191              0.120195
# États-Unis d'Amérique  1.823812  9.086692              2.365673
# Éthiopie               0.406788 -0.227394             -1.250207
# Îles Salomon          -0.278536 -0.263557             -0.953011
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                            -0.328896
# Afrique du Sud                          2.264583
# Albanie                                -0.280769
# Algérie                                -0.473275
# Allemagne                               4.018524
# ...                                          ...
# Émirats arabes unis                     1.831446
# Équateur                               -0.483970
# États-Unis d'Amérique                   0.173758
# Éthiopie                               -0.478622
# Îles Salomon                           -0.451885
#
#                        production_chicken_(milliers)  kmeans_cluster
# pays
# Afghanistan                                -0.279547               0
# Afrique du Sud                              0.377630               0
# Albanie                                    -0.285561               0
# Algérie                                    -0.180509               0
# Allemagne                                   0.316283               2
# ...                                              ...             ...
# Émirats arabes unis                        -0.271528               0
# Équateur                                   -0.154447               0
# États-Unis d'Amérique                       8.495910               4
# Éthiopie                                   -0.285160               0
# Îles Salomon                               -0.290774               0
#
# [168 rows x 6 columns]

# %% [markdown]
# ### 3. KMEANS (sur df_scaled)
# ---

# %%
# On fait un kmeans sur de df standardisé
df_scaled
# Out:
#                        pop_2017  pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan           -0.047467 -0.255191             -1.167652
# Afrique du Sud         0.086752 -0.081418              1.110847
# Albanie               -0.263969 -0.258012              0.153217
# Algérie               -0.014465 -0.182600             -0.886968
# Allemagne              0.252949  1.507692             -0.077935
# ...                         ...       ...                   ...
# Émirats arabes unis   -0.221183 -0.079136              1.176891
# Équateur              -0.173892 -0.214191              0.120195
# États-Unis d'Amérique  1.823812  9.086692              2.365673
# Éthiopie               0.406788 -0.227394             -1.250207
# Îles Salomon          -0.278536 -0.263557             -0.953011
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                            -0.328896
# Afrique du Sud                          2.264583
# Albanie                                -0.280769
# Algérie                                -0.473275
# Allemagne                               4.018524
# ...                                          ...
# Émirats arabes unis                     1.831446
# Équateur                               -0.483970
# États-Unis d'Amérique                   0.173758
# Éthiopie                               -0.478622
# Îles Salomon                           -0.451885
#
#                        production_chicken_(milliers)
# pays
# Afghanistan                                -0.279547
# Afrique du Sud                              0.377630
# Albanie                                    -0.285561
# Algérie                                    -0.180509
# Allemagne                                   0.316283
# ...                                              ...
# Émirats arabes unis                        -0.271528
# Équateur                                   -0.154447
# États-Unis d'Amérique                       8.495910
# Éthiopie                                   -0.285160
# Îles Salomon                               -0.290774
#
# [168 rows x 5 columns]

# %%
# Recherche pour trouver le nombre de cluster opti

# %%
# On part sur x cluster
k_list = range(1, 10)
list(k_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# On défini une liste vide poury stocker l'inertie des clusters
intertia = []
# On entraine kmeans en boucle pour faire des cluster de 1 à x comme défini plus haut et récupérer l'inertie de chaque cluster
for i in k_list :
  kmeans = KMeans(n_clusters=i) # On entraine kmeans sur un nombre de cluster test
  kmeans.fit(df_scaled) 
  intertia.append(kmeans.inertia_) # On ajoute l'inertie de chaque cluster dans une liste
# Out:
# C:\Users\david\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
intertia
# Out:
# [840.0000000000001,
#  536.4337326520423,
#  392.0371879547233,
#  288.3172471175774,
#  215.49824259019258,
#  182.5851307146536,
#  149.90653439084628,
#  115.53988367690434,
#  85.8190796471229]

# %%
# On trace l'inertie par cluster (méthode du coude)
fig, ax = plt.subplots(1,1,figsize=(12,6))

ax.set_ylabel("intertia")
ax.set_xlabel("n_cluster")
ax = plt.plot(k_list, intertia)

plt.title('Inertie par nombre de cluster')
plt.show()

# %%
# D'après le graph, on choisi 5 cluster voir 6
# Toutefois ce n'est pas asser marqué, revoir les données d'entrées ?
# Trouver des features qui permettent de mieux différencier les  pays, donc mieux faire les clusters
kmeans = KMeans(n_clusters=5)
# On entraine kmeans
kmeans.fit(df_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
# On récupère les clusters donnés par kmeans
kmean_cluster = pd.DataFrame(kmeans.labels_).rename(columns = {0 : 'kmean_cluster'})
kmean_cluster
# Out:
#      kmean_cluster
# 0                2
# 1                0
# 2                2
# 3                2
# 4                0
# ..             ...
# 163              0
# 164              2
# 165              1
# 166              2
# 167              2
#
# [168 rows x 1 columns]

# %%
# Centroides des cluster
kmeans.cluster_centers_
# Out:
# array([[ 0.06922668,  0.95912735,  0.63753569,  3.07337465,  0.20190829],
#        [ 1.82381246,  9.08669203,  2.36567312,  0.17375801,  8.49590991],
#        [-0.11365553, -0.19680051, -0.62439684, -0.24463551, -0.19946355],
#        [-0.1652974 , -0.13934725,  1.11414939, -0.26611744,  0.02948255],
#        [ 8.65842878,  3.32079714, -0.70534818,  0.72453812,  4.07590402]])

# %%
# Features du kmeans
kmeans.feature_names_in_
# Out:
# array(['pop_2017', 'pib_2017', 'dispo_chicken_(kcal)',
#        'import_chicken_(milliers)', 'production_chicken_(milliers)'],
#       dtype=object)

# %%
# On regarde le nombre d'individus par cluster
# Ce clustering est bizarre...
kmean_cluster['kmean_cluster'].value_counts()
# Out:
# 2    103
# 3     50
# 0     12
# 4      2
# 1      1
# Name: kmean_cluster, dtype: int64

# %%
# On ajoute les cluster kmeans au df_scaled
df_scaled_kmeans = df_scaled.copy()
df_scaled_kmeans['kmeans_cluster'] = kmeans.labels_
df_scaled_kmeans
# Out:
#                        pop_2017  pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan           -0.047467 -0.255191             -1.167652
# Afrique du Sud         0.086752 -0.081418              1.110847
# Albanie               -0.263969 -0.258012              0.153217
# Algérie               -0.014465 -0.182600             -0.886968
# Allemagne              0.252949  1.507692             -0.077935
# ...                         ...       ...                   ...
# Émirats arabes unis   -0.221183 -0.079136              1.176891
# Équateur              -0.173892 -0.214191              0.120195
# États-Unis d'Amérique  1.823812  9.086692              2.365673
# Éthiopie               0.406788 -0.227394             -1.250207
# Îles Salomon          -0.278536 -0.263557             -0.953011
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                            -0.328896
# Afrique du Sud                          2.264583
# Albanie                                -0.280769
# Algérie                                -0.473275
# Allemagne                               4.018524
# ...                                          ...
# Émirats arabes unis                     1.831446
# Équateur                               -0.483970
# États-Unis d'Amérique                   0.173758
# Éthiopie                               -0.478622
# Îles Salomon                           -0.451885
#
#                        production_chicken_(milliers)  kmeans_cluster
# pays
# Afghanistan                                -0.279547               2
# Afrique du Sud                              0.377630               0
# Albanie                                    -0.285561               2
# Algérie                                    -0.180509               2
# Allemagne                                   0.316283               0
# ...                                              ...             ...
# Émirats arabes unis                        -0.271528               0
# Équateur                                   -0.154447               2
# États-Unis d'Amérique                       8.495910               1
# Éthiopie                                   -0.285160               2
# Îles Salomon                               -0.290774               2
#
# [168 rows x 6 columns]

# %%
# sns.pairplot(df_scaled_kmeans, hue="cluster", palette = 'OrRd')

# %% [markdown]
# ### 3. ACP (sur df_scaled)
# ---

# %%
df_scaled
# Out:
#                        pop_2017  pib_2017  dispo_chicken_(kcal)  \
# pays
# Afghanistan           -0.047467 -0.255191             -1.167652
# Afrique du Sud         0.086752 -0.081418              1.110847
# Albanie               -0.263969 -0.258012              0.153217
# Algérie               -0.014465 -0.182600             -0.886968
# Allemagne              0.252949  1.507692             -0.077935
# ...                         ...       ...                   ...
# Émirats arabes unis   -0.221183 -0.079136              1.176891
# Équateur              -0.173892 -0.214191              0.120195
# États-Unis d'Amérique  1.823812  9.086692              2.365673
# Éthiopie               0.406788 -0.227394             -1.250207
# Îles Salomon          -0.278536 -0.263557             -0.953011
#
#                        import_chicken_(milliers)  \
# pays
# Afghanistan                            -0.328896
# Afrique du Sud                          2.264583
# Albanie                                -0.280769
# Algérie                                -0.473275
# Allemagne                               4.018524
# ...                                          ...
# Émirats arabes unis                     1.831446
# Équateur                               -0.483970
# États-Unis d'Amérique                   0.173758
# Éthiopie                               -0.478622
# Îles Salomon                           -0.451885
#
#                        production_chicken_(milliers)
# pays
# Afghanistan                                -0.279547
# Afrique du Sud                              0.377630
# Albanie                                    -0.285561
# Algérie                                    -0.180509
# Allemagne                                   0.316283
# ...                                              ...
# Émirats arabes unis                        -0.271528
# Équateur                                   -0.154447
# États-Unis d'Amérique                       8.495910
# Éthiopie                                   -0.285160
# Îles Salomon                               -0.290774
#
# [168 rows x 5 columns]

# %%
# Définition du nombre de composantes voulues
n_components = 4

# %%
pca = PCA(n_components=n_components)

# %%
# On entraine sur nos données standardisées
pca.fit(df_scaled)
# Out:
# PCA(n_components=4)

# %%
# Variance expliquée
pca.explained_variance_ratio_
# Out:
# array([0.48448935, 0.22230729, 0.16813931, 0.08994437])

# %%
# % de variance expliqué par composantes
scree = (pca.explained_variance_ratio_*100).round(2)
scree
# Out:
# array([48.45, 22.23, 16.81,  8.99])

# %%
# Somme cumulée des variances expliquées
scree_cum = scree.cumsum().round()
scree_cum
# Out:
# array([48., 71., 87., 96.])

# %%
# Nombre de composantes qui expliquent la variance
print(len(scree_cum), 'composantes expliquent', scree_cum[-1], '% de la variance')
# Out:
# 4 composantes expliquent 96.0 % de la variance

# %%
x_list = range(1, n_components+1)
list(x_list)
# Out:
# [1, 2, 3, 4]

# %%
plt.bar(x_list, scree)
plt.plot(x_list, scree_cum,c="red",marker='o')
plt.xlabel("rang de l'axe d'inertie")
plt.ylabel("pourcentage d'inertie")
plt.title("Eboulis des valeurs propres")
plt.show(block=False)

# %%
# Composantes par colonnes
pcs = pca.components_
pcs
# Out:
# array([[ 0.47594167,  0.57181459,  0.17144802,  0.26503491,  0.58895643],
#        [ 0.42014317,  0.01053181, -0.7838809 , -0.4498427 ,  0.08087689],
#        [ 0.06042616, -0.07768635, -0.47669102,  0.84652459, -0.21558128],
#        [ 0.73429381, -0.55889916,  0.34229811,  0.04552762, -0.17089051]])

# %%
pcs = pd.DataFrame(pcs)
pcs
# Out:
#           0         1         2         3         4
# 0  0.475942  0.571815  0.171448  0.265035  0.588956
# 1  0.420143  0.010532 -0.783881 -0.449843  0.080877
# 2  0.060426 -0.077686 -0.476691  0.846525 -0.215581
# 3  0.734294 -0.558899  0.342298  0.045528 -0.170891

# %%
features = df_scaled.columns
features
# Out:
# Index(['pop_2017', 'pib_2017', 'dispo_chicken_(kcal)',
#        'import_chicken_(milliers)', 'production_chicken_(milliers)'],
#       dtype='object')

# %%
# On regarde les composantes par catégorie
pcs.columns = features
pcs.index = [f"F{i}" for i in x_list]
pcs.round(2)
# Out:
#     pop_2017  pib_2017  dispo_chicken_(kcal)  import_chicken_(milliers)  \
# F1      0.48      0.57                  0.17                       0.27
# F2      0.42      0.01                 -0.78                      -0.45
# F3      0.06     -0.08                 -0.48                       0.85
# F4      0.73     -0.56                  0.34                       0.05
#
#     production_chicken_(milliers)
# F1                           0.59
# F2                           0.08
# F3                          -0.22
# F4                          -0.17

# %%
# df des composantes par catégories
pcs.T.round(2)
# Out:
#                                  F1    F2    F3    F4
# pop_2017                       0.48  0.42  0.06  0.73
# pib_2017                       0.57  0.01 -0.08 -0.56
# dispo_chicken_(kcal)           0.17 -0.78 -0.48  0.34
# import_chicken_(milliers)      0.27 -0.45  0.85  0.05
# production_chicken_(milliers)  0.59  0.08 -0.22 -0.17

# %%
# Cercle de corrélations

# %%
# Fonction pour cercle de corrélation

# %%
def correlation_graph(pca, 
                      x_y, 
                      features) : 
    """Affiche le graphe des correlations

    Positional arguments : 
    -----------------------------------
    pca : sklearn.decomposition.PCA : notre objet PCA qui a été fit
    x_y : list ou tuple : le couple x,y des plans à afficher, exemple [0,1] pour F1, F2
    features : list ou tuple : la liste des features (ie des dimensions) à représenter
    """

    # Extrait x et y 
    x,y=x_y

    # Taille de l'image (en inches)
    fig, ax = plt.subplots(figsize=(10, 9))

    # Pour chaque composante : 
    for i in range(0, pca.components_.shape[1]):

        # Les flèches
        ax.arrow(0,0, 
                pca.components_[x, i],  
                pca.components_[y, i],  
                head_width=0.07,
                head_length=0.07, 
                width=0.02, )

        # Les labels
        plt.text(pca.components_[x, i] + 0.05,
                pca.components_[y, i] + 0.05,
                features[i])
        
    # Affichage des lignes horizontales et verticales
    plt.plot([-1, 1], [0, 0], color='grey', ls='--')
    plt.plot([0, 0], [-1, 1], color='grey', ls='--')

    # Nom des axes, avec le pourcentage d'inertie expliqué
    plt.xlabel('F{} ({}%)'.format(x+1, round(100*pca.explained_variance_ratio_[x],1)))
    plt.ylabel('F{} ({}%)'.format(y+1, round(100*pca.explained_variance_ratio_[y],1)))

    # J'ai copié collé le code sans le lire
    plt.title("Cercle des corrélations (F{} et F{})".format(x+1, y+1))

    # Le cercle 
    an = np.linspace(0, 2 * np.pi, 100)
    plt.plot(np.cos(an), np.sin(an))  # Add a unit circle for scale

    # Axes et display
    plt.axis('equal')
    plt.show(block=False)

# %%
# On sélectionne les deux axes de projection pour le cercle de corrélations
x_y = (0, 1)
x_y
correlation_graph(pca, x_y, features)

# %%
# Calcul des coordonnées de projection par individus
# On entraine et ontransforme sur df_scaled
X_proj = pca.fit_transform(df_scaled)
X_proj[:5]
# Out:
# array([[-0.62051491,  1.01801219,  0.35541281, -0.25911633],
#        [ 1.00778666, -1.82334595,  1.31765192,  0.52801456],
#        [-0.48949676, -0.13051906, -0.24506013,  0.03883498],
#        [-0.49511345,  0.88557662,  0.07439655, -0.20287402],
#        [ 2.22047349, -1.59887828,  3.26890341, -0.55468206]])

# %%
# Fonction pour projection des individus sur les axes

# %%
def display_factorial_planes(   X_projected, 
                                x_y, 
                                pca=None, 
                                labels = None,
                                clusters=None, 
                                alpha=1,
                                figsize=[10,8], 
                                marker="." ):
    """
    Affiche la projection des individus

    Positional arguments : 
    -------------------------------------
    X_projected : np.array, pd.DataFrame, list of list : la matrice des points projetés
    x_y : list ou tuple : le couple x,y des plans à afficher, exemple [0,1] pour F1, F2

    Optional arguments : 
    -------------------------------------
    pca : sklearn.decomposition.PCA : un objet PCA qui a été fit, cela nous permettra d'afficher la variance de chaque composante, default = None
    labels : list ou tuple : les labels des individus à projeter, default = None
    clusters : list ou tuple : la liste des clusters auquel appartient chaque individu, default = None
    alpha : float in [0,1] : paramètre de transparence, 0=100% transparent, 1=0% transparent, default = 1
    figsize : list ou tuple : couple width, height qui définit la taille de la figure en inches, default = [10,8] 
    marker : str : le type de marker utilisé pour représenter les individus, points croix etc etc, default = "."
    """

    # Transforme X_projected en np.array
    X_ = np.array(X_projected)

    # On définit la forme de la figure si elle n'a pas été donnée
    if not figsize: 
        figsize = (7,6)

    # On gère les labels
    if  labels is None : 
        labels = []
    try : 
        len(labels)
    except Exception as e : 
        raise e

    # On vérifie la variable axis 
    if not len(x_y) ==2 : 
        raise AttributeError("2 axes sont demandées")   
    if max(x_y )>= X_.shape[1] : 
        raise AttributeError("la variable axis n'est pas bonne")   

    # on définit x et y 
    x, y = x_y

    # Initialisation de la figure       
    fig, ax = plt.subplots(1, 1, figsize=figsize)

    # On vérifie s'il y a des clusters ou non
    c = None if clusters is None else clusters
 
    # Les points    
    # plt.scatter(   X_[:, x], X_[:, y], alpha=alpha, 
    #                     c=c, cmap="Set1", marker=marker)
    sns.scatterplot(data=None, x=X_[:, x], y=X_[:, y], hue=c)

    # Si la variable pca a été fournie, on peut calculer le % de variance de chaque axe 
    if pca : 
        v1 = str(round(100*pca.explained_variance_ratio_[x]))  + " %"
        v2 = str(round(100*pca.explained_variance_ratio_[y]))  + " %"
    else : 
        v1=v2= ''

    # Nom des axes, avec le pourcentage d'inertie expliqué
    ax.set_xlabel(f'F{x+1} {v1}')
    ax.set_ylabel(f'F{y+1} {v2}')

    # Valeur x max et y max
    x_max = np.abs(X_[:, x]).max() *1.1
    y_max = np.abs(X_[:, y]).max() *1.1

    # On borne x et y 
    ax.set_xlim(left=-x_max, right=x_max)
    ax.set_ylim(bottom= -y_max, top=y_max)

    # Affichage des lignes horizontales et verticales
    plt.plot([-x_max, x_max], [0, 0], color='grey', alpha=0.8)
    plt.plot([0,0], [-y_max, y_max], color='grey', alpha=0.8)

    # Affichage des labels des points
    if len(labels) : 
        # j'ai copié collé la fonction sans la lire... Hahaha, oui, c'est tout a fait mon genre mdr
        for i,(_x,_y) in enumerate(X_[:,[x,y]]):
            plt.text(_x, _y+0.05, labels[i], fontsize='10', ha='center',va='center') 

    # Titre et display
    plt.title(f"Projection des individus (sur F{x+1} et F{y+1})")
    
    plt.show()

# %%
# On projete les individus sur F'x' et on les tri par les cluster que nous avons chercher sur les composantes
# On remarque que certains pays sont très éloignés...
# labels = df_with_pca_cluster['pays'] - Pour rajouter les labels
x_y = [0,1] # Choix des composantes de l'ACP à représenter dans le plan
display_factorial_planes(X_proj, x_y, clusters = df_scaled_kmeans['kmeans_cluster'], pca = pca, labels = df_scaled_kmeans.index)

# %%
# On remarque trois pays vraiment très écartés, outliers  ?

# %% [markdown]
# # FIN

# %% [raw]
# --- Conclusion et remarques après première run ---
#
# Nettoyage des données à approfondir au cas ou, surtout sur valeurs manquantes
# Voir aussi si possibilité de retirer des pays qui ne seraient pas pertinents pour l'export de nos poulets (exemple :  USA et Chine qui n'ont surement pas besoin d'en importer...)
#
# Choix de quelques données par pays pour une première approche
# Clustering asser "bizarre", deux clusters avec seulement 1 ou deux pays
#     Malgré un scale sur les données ces pays sont peut être trop extrêmes
#
#     Méthode du coude : cassure pas vraiment franche entre deux ou 5 clusters
#     Dendogramme : on remarque une très petite partie qui se détache et difficile de trouver ou placer notre ligne de démarcation
#
#     ACP : Si l'on prend les deux premières composantes (facilité à représenter nos données sur un plan), seulement 71% de la variance expliquée, ce qui n'est pas génial
#
#
# --- Idées pour la seconde run ---
#
# Revoir les features sélectionnées pour mieux différencier les pays (bien regarder le VIF pour que ces features soient bien différentes)
# Traiter les outliers
# Enlever les pays qui ne seraient pas pertinents pour notre analyse
# Refaire une run et bien observer les clusters
# Regarder les centroides
# Comparer les deux méthodes de clustering
# Regarder l'ACP également et le cercle de corrélations (l'interpreter)
# Sortir un csv final avec les données utiles pour faire notre choix de pays dans un autre notebook
